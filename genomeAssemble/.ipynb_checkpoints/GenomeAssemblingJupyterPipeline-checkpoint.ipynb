# %% [markdown]
# # Pipeline to Assemble the genome of bacteria
#
# Combination of two bacteria genome assembling pipelines, Tychus and Mypro.
# Realization of Tychus with Python scripts. Add SOAPdenovo, improve the genus database for prokka with data from Mypro https://sourceforge.net/projects/sb2nhri/files/MyPro/

# %% [markdown]
# ## setup the files and parameters you are going to work with.

# %% [markdown]
# ### two reads files

# %%
read1 = '/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_1.fq.gz'
read2 = '/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_2.fq.gz'

# %% [markdown]
# ### parameters

# %%
thread = 24
outfolder = '/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus'
bacteriaStrain = 'MNH08365' # change as needed
cleanOrNot = True # whether or not to remove intermediate files

# %% [markdown]
# ### usually fixed parameters

# %%
adapters = '/home/p/Trimmomatic-0.38/adapters/TruSeq3-PE.fa'

# %% [markdown]
# ## import required packages

# %%
import subprocess
import os
import shutil
from Bio import SeqIO
import time

# %% [markdown]
# ## set up some constants
# Below are some programs that will be used

# %%
## program fastqc
FASTQC = '/home/p/FastQC/fastqc'
## program, Trim reads
TRIMMOMATIC = '/home/p/Trimmomatic-0.38/trimmomatic-0.38.jar'
## program, reads quality report and Trim
FASTP = '/home/p/fastp/fastp'
## program, Identify the best kmer for genome assembling
KMERGENIE = '/home/p/KmerGenie/kmergenie-1.7048/kmergenie'
## program, assemble the genome
ABYSS = '/home/p/anaconda/anaconda3_5.2.0/bin/abyss-pe'
## program, assemble the genome
VELVETH = '/home/p/anaconda/anaconda3_5.2.0/bin/velveth'
VELVETG = '/home/p/anaconda/anaconda3_5.2.0/bin/velvetg'
## program, assemble the genome
SPADES = '/home/p/anaconda/anaconda3_5.2.0/bin/spades.py'
## program, assemble the genome
FQ2FA = '/home/p/anaconda/anaconda3_5.2.0/bin/fq2fa'
IDBA_UD = '/home/p/anaconda/anaconda3_5.2.0/bin/idba_ud'
## program, assemble the genome
SOAPDENOVO = '/home/p/anaconda/anaconda3_5.2.0/bin/SOAPdenovo-127mer'
## program, merge assembled results
MERGE = '/home/p/CISA/CISA1.3/Merge.py'
CISAPATH = '/home/p/CISA/CISA1.3/'
CISA = '/home/p/CISA/CISA1.3/CISA.py'
## program, merge assembled results
NOVO_STITCH = '/home/p/Novo_Stitch/scripts/main.py'
REFALIGNER = '/home/p/RefalignerAssembler/latest/RefAligner'
GLPK = '/usr/local/bin/glpsol'
## program, annotate merged genome
PROKKA = '/home/p/prokka/prokka-master/bin/prokka'
## program, evaluate result
QUAST = '/home/p/quast/quast-4.6.3/quast.py'

## used programs
NCUMER = '/home/p/quast/quast-4.6.3/quast_libs/MUMmer/nucmer'
MAKEBLASTDB = '/home/p/blast/bin/makeblastdb'
BLASTN = '/home/p/blast/bin/blastn'

# %% [markdown]
# ## check quality of input reads with fastqc

# %% [markdown]
# creat the folder to store fastqc result

# %%
if not os.path.exists(outfolder):
    os.mkdir(outfolder)
os.chdir(outfolder)
if not os.path.exists('fastqc'):
    os.mkdir('fastqc')

# %% [markdown]
# run the command

# %%
command_line = '{FASTQC} {read1} {read2} -t {thread} -o {outfolder}/fastqc'.format( \
               FASTQC = FASTQC, read1 = read1, read2 = read2, thread = thread, outfolder = outfolder)
print(command_line)
subprocess.run(command_line,shell=True)
# Out:
# /home/p/FastQC/fastqc /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_1.fq.gz /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_2.fq.gz -w 24 -o /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/fastqc
# CompletedProcess(args='/home/p/FastQC/fastqc /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_1.fq.gz /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_2.fq.gz -w 24 -o /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/fastqc', returncode=0)

# %% [markdown]
# ## trim reads with TRIMMOMATIC

# %% [markdown]
# creat the folder to store the result

# %%
if not os.path.exists('Trimmomatic'):
    os.mkdir('Trimmomatic')

# %%
command_line = '''java -jar {TRIMMOMATIC} PE -threads {thread} -phred33 {read1} {read2} \
                ./Trimmomatic/read1.pair.fq ./Trimmomatic/read1.single.fq ./Trimmomatic/read2.pair.fq ./Trimmomatic/read2.single.fq \
                ILLUMINACLIP:{adapters}:2:30:10 SLIDINGWINDOW:4:20 MINLEN:50 '''.format( \
               TRIMMOMATIC = TRIMMOMATIC, read1 = read1, read2 = read2, thread = thread, adapters = adapters)
print(command_line)
result = subprocess.run(command_line,shell=True, check=True)
print(result)
# Out:
# java -jar /home/p/Trimmomatic-0.38/trimmomatic-0.38.jar PE -threads 24 -phred33 /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_1.fq.gz /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_2.fq.gz                 ./Trimmomatic/read1.pair.fq ./Trimmomatic/read1.single.fq ./Trimmomatic/read2.pair.fq ./Trimmomatic/read2.single.fq                 ILLUMINACLIP:/home/p/Trimmomatic-0.38/adapters/TruSeq3-PE.fa:2:30:10 SLIDINGWINDOW:4:20 MINLEN:50
# CompletedProcess(args='java -jar /home/p/Trimmomatic-0.38/trimmomatic-0.38.jar PE -threads 24 -phred33 /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_1.fq.gz /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/MNH08365_2.fq.gz                 ./Trimmomatic/read1.pair.fq ./Trimmomatic/read1.single.fq ./Trimmomatic/read2.pair.fq ./Trimmomatic/read2.single.fq                 ILLUMINACLIP:/home/p/Trimmomatic-0.38/adapters/TruSeq3-PE.fa:2:30:10 SLIDINGWINDOW:4:20 MINLEN:50 ', returncode=0)

# %% [markdown]
# ## Identify best kmer with kmergenie

# %%
if not os.path.exists('kmergenie'):
    os.mkdir('kmergenie')
fout = open('readlist.txt','w')
fout.write(os.path.join(outfolder,'Trimmomatic','read1.pair.fq') + '\n')
fout.write(os.path.join(outfolder,'Trimmomatic','read2.pair.fq') + '\n')
fout.close()

# %%
command_line = '''{KMERGENIE} {outfolder}/readlist.txt -t {thread} -o {outfolder}/kmergenie/kmergenie.histogram '''.format( \
               KMERGENIE = KMERGENIE, outfolder = outfolder, thread = thread, adapters = adapters)
print(command_line)
result = subprocess.check_output(command_line, shell=True)
# Out:
# /home/p/KmerGenie/kmergenie-1.7048/kmergenie /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/readlist.txt -t 24 -o /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/kmergenie/kmergenie.histogram

# %%
result = result.decode('utf-8')
print(result)
# Out:
# running histogram estimation
# list of reads:
# /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq
# /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq
# Setting maximum kmer length to: 150 bp
# computing histograms (from k=21 to k=121): 121 111 101 91 81 71 51 61 41 31 21 estimation of the best k so far: 61
#
# ntCard wall-clock time over all k values: 34 seconds
# fitting model to histograms to estimate best k
# refining estimation around [55; 67], with a step of 2
# running histogram estimation
# list of reads:
# /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq
# /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq
# Setting maximum kmer length to: 150 bp
# computing histograms (from k=57 to k=67): 63 65 61 59 67 57 table of predicted num. of genomic k-mers: /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/kmergenie/kmergenie.histogram.dat
# recommended coverage cut-off for best k: 123
# best k: 61
#
# ntCard wall-clock time over all k values: 30 seconds
# fitting model to histograms to estimate best k

# %%
result.split('\n')[-5]
bestkmer = result.split('\n')[-5].split()[-1]
print('best kmer is ', bestkmer)
# Out:
# best kmer is  61

# %% [markdown]
# ## run abyss

# %%
if not os.path.exists('abyss'):
    os.mkdir('abyss')
os.chdir('abyss')

# %%
command_line = '''{ABYSS} k={bestkmer} np={thread}  in="{read1} {read2}" name=abyss'''.format( \
               ABYSS = ABYSS, bestkmer=bestkmer, outfolder = outfolder, thread = thread, \
               read1 = os.path.join(outfolder,'Trimmomatic','read1.pair.fq'), read2 = os.path.join(outfolder,'Trimmomatic','read2.pair.fq'))
print(command_line)
result = subprocess.check_output(command_line, shell=True)
# Out:
# /home/p/anaconda/anaconda3_5.2.0/bin/abyss-pe k=61 np=24  in="/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq" name=abyss

# %%
result = result.decode('utf-8')
print(result)
os.chdir('..')
# Out:
# /home/p/anaconda/anaconda3_5.2.0/bin/mpirun -np 24 ABYSS-P -k61 -q3    --coverage-hist=coverage.hist -s abyss-bubbles.fa  -o abyss-1.fa /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq
# ABySS 2.1.0
# ABYSS-P -k61 -q3 --coverage-hist=coverage.hist -s abyss-bubbles.fa -o abyss-1.fa /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq
# Running on 24 processors
# 1: Running on host localhost.localdomain
# 2: Running on host localhost.localdomain
# 4: Running on host localhost.localdomain
# 6: Running on host localhost.localdomain
# 9: Running on host localhost.localdomain
# 10: Running on host localhost.localdomain
# 11: Running on host localhost.localdomain
# 12: Running on host localhost.localdomain
# 13: Running on host localhost.localdomain
# 14: Running on host localhost.localdomain
# 16: Running on host localhost.localdomain
# 17: Running on host localhost.localdomain
# 18: Running on host localhost.localdomain
# 19: Running on host localhost.localdomain
# 20: Running on host localhost.localdomain
# 21: Running on host localhost.localdomain
# 22: Running on host localhost.localdomain
# 0: Running on host localhost.localdomain
# 3: Running on host localhost.localdomain
# 5: Running on host localhost.localdomain
# 7: Running on host localhost.localdomain
# 8: Running on host localhost.localdomain
# 15: Running on host localhost.localdomain
# 23: Running on host localhost.localdomain
# 0: Reading `/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq'...
# 1: Reading `/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq'...
# 0: Loaded 4411541 k-mer.
# 22: Loaded 4426190 k-mer.
# 1: Loaded 4405095 k-mer.
# 23: Loaded 4414719 k-mer.
# 2: Loaded 4410692 k-mer.
# 3: Loaded 4412940 k-mer.
# 4: Loaded 4414846 k-mer.
# 5: Loaded 4417937 k-mer.
# 7: Loaded 4421887 k-mer.
# 6: Loaded 4412197 k-mer.
# 9: Loaded 4406039 k-mer.
# 10: Loaded 4407070 k-mer.
# 11: Loaded 4414708 k-mer.
# 12: Loaded 4420957 k-mer.
# 13: Loaded 4410235 k-mer.
# 8: Loaded 4419871 k-mer.
# 14: Loaded 4418390 k-mer.
# 16: Loaded 4417713 k-mer.
# 17: Loaded 4404158 k-mer.
# 18: Loaded 4410786 k-mer.
# 19: Loaded 4408002 k-mer.
# 20: Loaded 4416974 k-mer.
# 21: Loaded 4422534 k-mer.
# 15: Loaded 4407990 k-mer.
# Loaded 105933471 k-mer. At least 4.24 GB of RAM is required.
# Minimum k-mer coverage is 54
# Using a coverage threshold of 22...
# The median k-mer coverage is 490
# The reconstruction is 3038549
# The k-mer coverage threshold is 22.1359
# Setting parameter e (erode) to 22
# Setting parameter E (erodeStrand) to 1
# Setting parameter c (coverage) to 22.1359
# Finding adjacent k-mer...
# 15: Added 8907028 edges.
# 22: Added 8942759 edges.
# 1: Added 8899688 edges.
# 23: Added 8919642 edges.
# 2: Added 8911163 edges.
# 3: Added 8916224 edges.
# 4: Added 8920085 edges.
# 5: Added 8925728 edges.
# 7: Added 8934754 edges.
# 6: Added 8914696 edges.
# 9: Added 8901870 edges.
# 10: Added 8903937 edges.
# 11: Added 8919793 edges.
# 12: Added 8930858 edges.
# 13: Added 8911076 edges.
# 8: Added 8930577 edges.
# 14: Added 8927137 edges.
# 16: Added 8925336 edges.
# 17: Added 8897479 edges.
# 18: Added 8911182 edges.
# 19: Added 8905936 edges.
# 20: Added 8924361 edges.
# 21: Added 8936409 edges.
# 0: Added 8913498 edges.
# Added 214031216 edges.
# Eroding tips...
# 18: Eroded 2455582 tips.
# 21: Eroded 2560201 tips.
# 5: Eroded 2585392 tips.
# 0: Eroded 2601391 tips.
# 4: Eroded 2622314 tips.
# 13: Eroded 2625968 tips.
# 12: Eroded 2681442 tips.
# 14: Eroded 2680742 tips.
# 23: Eroded 2682742 tips.
# 22: Eroded 2697478 tips.
# 9: Eroded 2692702 tips.
# 10: Eroded 2700046 tips.
# 6: Eroded 2707606 tips.
# 8: Eroded 2717887 tips.
# 20: Eroded 2724011 tips.
# 19: Eroded 2749859 tips.
# 7: Eroded 2764654 tips.
# 2: Eroded 2763610 tips.
# 1: Eroded 2775742 tips.
# 3: Eroded 2781632 tips.
# 17: Eroded 2781637 tips.
# 15: Eroded 2792821 tips.
# 11: Eroded 2799821 tips.
# 16: Eroded 2814066 tips.
# 18: Eroded 376690 tips.
# 17: Eroded 47096 tips.
# 23: Eroded 152582 tips.
# 2: Eroded 71994 tips.
# 14: Eroded 157190 tips.
# 7: Eroded 75034 tips.
# 1: Eroded 57280 tips.
# 0: Eroded 232901 tips.
# 21: Eroded 280135 tips.
# 19: Eroded 82922 tips.
# 10: Eroded 132299 tips.
# 22: Eroded 145393 tips.
# 9: Eroded 138154 tips.
# 15: Eroded 41155 tips.
# 13: Eroded 207683 tips.
# 4: Eroded 214489 tips.
# 6: Eroded 128591 tips.
# 12: Eroded 159630 tips.
# 11: Eroded 36588 tips.
# 3: Eroded 52667 tips.
# 5: Eroded 250822 tips.
# 20: Eroded 112611 tips.
# 8: Eroded 122194 tips.
# 16: Eroded 25383 tips.
# Eroded 68060829 tips.
# Pruning tips shorter than 1 bp...
# 1: Pruned 0 tips.
# 4: Pruned 0 tips.
# 10: Pruned 0 tips.
# 16: Pruned 0 tips.
# 18: Pruned 0 tips.
# 6: Pruned 0 tips.
# 12: Pruned 0 tips.
# 15: Pruned 0 tips.
# 7: Pruned 0 tips.
# 14: Pruned 0 tips.
# 20: Pruned 0 tips.
# 0: Pruned 0 tips.
# 19: Pruned 0 tips.
# 22: Pruned 0 tips.
# 13: Pruned 0 tips.
# 9: Pruned 0 tips.
# 3: Pruned 0 tips.
# 8: Pruned 1 tips.
# 5: Pruned 0 tips.
# 11: Pruned 0 tips.
# 21: Pruned 0 tips.
# 2: Pruned 0 tips.
# 23: Pruned 0 tips.
# 17: Pruned 0 tips.
# Pruned 1 k-mer in 1 tips.
# Pruning tips shorter than 2 bp...
# 16: Pruned 0 tips.
# 10: Pruned 0 tips.
# 4: Pruned 0 tips.
# 1: Pruned 0 tips.
# 18: Pruned 0 tips.
# 6: Pruned 0 tips.
# 12: Pruned 0 tips.
# 15: Pruned 0 tips.
# 8: Pruned 0 tips.
# 22: Pruned 0 tips.
# 20: Pruned 0 tips.
# 19: Pruned 0 tips.
# 11: Pruned 0 tips.
# 3: Pruned 0 tips.
# 5: Pruned 0 tips.
# 9: Pruned 0 tips.
# 23: Pruned 0 tips.
# 13: Pruned 0 tips.
# 17: Pruned 0 tips.
# 7: Pruned 0 tips.
# 21: Pruned 0 tips.
# 0: Pruned 0 tips.
# 14: Pruned 0 tips.
# 2: Pruned 0 tips.
# Pruning tips shorter than 4 bp...
# 4: Pruned 0 tips.
# 10: Pruned 0 tips.
# 16: Pruned 0 tips.
# 18: Pruned 0 tips.
# 1: Pruned 0 tips.
# 6: Pruned 0 tips.
# 12: Pruned 0 tips.
# 15: Pruned 0 tips.
# 8: Pruned 0 tips.
# 20: Pruned 0 tips.
# 19: Pruned 0 tips.
# 22: Pruned 0 tips.
# 9: Pruned 0 tips.
# 14: Pruned 0 tips.
# 3: Pruned 0 tips.
# 21: Pruned 0 tips.
# 0: Pruned 0 tips.
# 11: Pruned 0 tips.
# 5: Pruned 0 tips.
# 13: Pruned 0 tips.
# 7: Pruned 0 tips.
# 23: Pruned 0 tips.
# 17: Pruned 0 tips.
# 2: Pruned 0 tips.
# Pruning tips shorter than 8 bp...
# 10: Pruned 0 tips.
# 4: Pruned 0 tips.
# 16: Pruned 0 tips.
# 1: Pruned 0 tips.
# 18: Pruned 0 tips.
# 6: Pruned 0 tips.
# 12: Pruned 0 tips.
# 8: Pruned 0 tips.
# 15: Pruned 0 tips.
# 22: Pruned 0 tips.
# 11: Pruned 0 tips.
# 14: Pruned 0 tips.
# 20: Pruned 0 tips.
# 19: Pruned 0 tips.
# 9: Pruned 0 tips.
# 3: Pruned 0 tips.
# 7: Pruned 0 tips.
# 5: Pruned 0 tips.
# 13: Pruned 1 tips.
# 23: Pruned 0 tips.
# 17: Pruned 0 tips.
# 21: Pruned 0 tips.
# 0: Pruned 0 tips.
# 2: Pruned 0 tips.
# Pruned 8 k-mer in 1 tips.
# Pruning tips shorter than 16 bp...
# 16: Pruned 0 tips.
# 1: Pruned 0 tips.
# 18: Pruned 0 tips.
# 4: Pruned 0 tips.
# 6: Pruned 0 tips.
# 12: Pruned 0 tips.
# 8: Pruned 0 tips.
# 15: Pruned 0 tips.
# 22: Pruned 0 tips.
# 20: Pruned 0 tips.
# 19: Pruned 0 tips.
# 14: Pruned 0 tips.
# 3: Pruned 0 tips.
# 7: Pruned 0 tips.
# 5: Pruned 0 tips.
# 21: Pruned 0 tips.
# 13: Pruned 0 tips.
# 23: Pruned 0 tips.
# 0: Pruned 0 tips.
# 9: Pruned 0 tips.
# 17: Pruned 0 tips.
# 10: Pruned 0 tips.
# 2: Pruned 0 tips.
# 11: Pruned 0 tips.
# Pruning tips shorter than 32 bp...
# 10: Pruned 0 tips.
# 4: Pruned 0 tips.
# 16: Pruned 0 tips.
# 18: Pruned 0 tips.
# 6: Pruned 0 tips.
# 1: Pruned 0 tips.
# 12: Pruned 0 tips.
# 8: Pruned 0 tips.
# 15: Pruned 0 tips.
# 22: Pruned 0 tips.
# 20: Pruned 0 tips.
# 14: Pruned 0 tips.
# 19: Pruned 0 tips.
# 17: Pruned 0 tips.
# 9: Pruned 0 tips.
# 3: Pruned 0 tips.
# 21: Pruned 0 tips.
# 5: Pruned 0 tips.
# 0: Pruned 0 tips.
# 11: Pruned 0 tips.
# 7: Pruned 0 tips.
# 23: Pruned 0 tips.
# 2: Pruned 0 tips.
# 13: Pruned 0 tips.
# Pruning tips shorter than 61 bp...
# 4: Pruned 0 tips.
# 10: Pruned 0 tips.
# 16: Pruned 0 tips.
# 6: Pruned 0 tips.
# 8: Pruned 0 tips.
# 18: Pruned 0 tips.
# 12: Pruned 0 tips.
# 22: Pruned 0 tips.
# 19: Pruned 0 tips.
# 20: Pruned 0 tips.
# 15: Pruned 0 tips.
# 14: Pruned 0 tips.
# 1: Pruned 0 tips.
# 11: Pruned 0 tips.
# 3: Pruned 0 tips.
# 5: Pruned 0 tips.
# 23: Pruned 0 tips.
# 17: Pruned 0 tips.
# 13: Pruned 0 tips.
# 7: Pruned 0 tips.
# 9: Pruned 0 tips.
# 21: Pruned 0 tips.
# 2: Pruned 0 tips.
# 0: Pruned 0 tips.
# Pruned 2 tips in 6 rounds.
# Marking ambiguous branches...
# 12: Marked 112083 edges of 54679 ambiguous vertices.
# 19: Marked 111885 edges of 54607 ambiguous vertices.
# 4: Marked 113004 edges of 55126 ambiguous vertices.
# 1: Marked 111989 edges of 54691 ambiguous vertices.
# 11: Marked 112369 edges of 54833 ambiguous vertices.
# 16: Marked 112534 edges of 54861 ambiguous vertices.
# 23: Marked 112164 edges of 54721 ambiguous vertices.
# 15: Marked 112522 edges of 54863 ambiguous vertices.
# 8: Marked 112092 edges of 54675 ambiguous vertices.
# 13: Marked 111863 edges of 54564 ambiguous vertices.
# 5: Marked 112552 edges of 54906 ambiguous vertices.
# 2: Marked 111931 edges of 54627 ambiguous vertices.
# 18: Marked 111338 edges of 54347 ambiguous vertices.
# 17: Marked 112230 edges of 54783 ambiguous vertices.
# 7: Marked 112594 edges of 54895 ambiguous vertices.
# 14: Marked 112903 edges of 55060 ambiguous vertices.
# 6: Marked 111923 edges of 54604 ambiguous vertices.
# 9: Marked 111977 edges of 54642 ambiguous vertices.
# 10: Marked 111421 edges of 54364 ambiguous vertices.
# 20: Marked 113251 edges of 55217 ambiguous vertices.
# 21: Marked 112898 edges of 55053 ambiguous vertices.
# 3: Marked 113105 edges of 55171 ambiguous vertices.
# 0: Marked 112268 edges of 54771 ambiguous vertices.
# 22: Marked 112991 edges of 55138 ambiguous vertices.
# Marked 1315198 ambiguous branches.
# Removing low-coverage contigs (mean k-mer coverage < 22.1359)...
# 12: Found 1572799 k-mer in 67105 contigs before removing low-coverage contigs.
# Removed 1446922 k-mer in 28880 low-coverage contigs.
# 10: Found 1571336 k-mer in 66851 contigs before removing low-coverage contigs.
# Removed 1446357 k-mer in 28692 low-coverage contigs.
# 3: Found 1562677 k-mer in 67001 contigs before removing low-coverage contigs.
# Removed 1435657 k-mer in 28667 low-coverage contigs.
# 0: Found 1577130 k-mer in 67123 contigs before removing low-coverage contigs.
# Removed 1450163 k-mer in 28883 low-coverage contigs.
# 4: Found 1588017 k-mer in 67364 contigs before removing low-coverage contigs.
# Removed 1461467 k-mer in 28958 low-coverage contigs.
# 21: Found 1560368 k-mer in 66866 contigs before removing low-coverage contigs.
# Removed 1432839 k-mer in 28335 low-coverage contigs.
# 9: Found 1576059 k-mer in 66937 contigs before removing low-coverage contigs.
# Removed 1449124 k-mer in 28692 low-coverage contigs.
# 16: Found 1574410 k-mer in 66995 contigs before removing low-coverage contigs.
# Removed 1447964 k-mer in 28718 low-coverage contigs.
# 15: Found 1578890 k-mer in 67449 contigs before removing low-coverage contigs.
# Removed 1451504 k-mer in 28897 low-coverage contigs.
# 1: Found 1578155 k-mer in 67213 contigs before removing low-coverage contigs.
# Removed 1451529 k-mer in 28827 low-coverage contigs.
# 11: Found 1577608 k-mer in 66897 contigs before removing low-coverage contigs.
# Removed 1451382 k-mer in 28751 low-coverage contigs.
# 6: Found 1570280 k-mer in 66920 contigs before removing low-coverage contigs.
# Removed 1444386 k-mer in 28739 low-coverage contigs.
# 2: Found 1580908 k-mer in 67070 contigs before removing low-coverage contigs.
# Removed 1454273 k-mer in 28797 low-coverage contigs.
# 17: Found 1593575 k-mer in 67146 contigs before removing low-coverage contigs.
# Removed 1467411 k-mer in 29215 low-coverage contigs.
# 22: Found 1588544 k-mer in 67790 contigs before removing low-coverage contigs.
# Removed 1460978 k-mer in 29132 low-coverage contigs.
# 18: Found 1592922 k-mer in 67296 contigs before removing low-coverage contigs.
# Removed 1466082 k-mer in 29022 low-coverage contigs.
# 23: Found 1580522 k-mer in 67052 contigs before removing low-coverage contigs.
# Removed 1454833 k-mer in 29046 low-coverage contigs.
# 14: Found 1574472 k-mer in 67309 contigs before removing low-coverage contigs.
# Removed 1447748 k-mer in 28813 low-coverage contigs.
# 19: Found 1582881 k-mer in 66895 contigs before removing low-coverage contigs.
# Removed 1457134 k-mer in 28849 low-coverage contigs.
# 8: Found 1558206 k-mer in 66601 contigs before removing low-coverage contigs.
# Removed 1431648 k-mer in 28430 low-coverage contigs.
# 7: Found 1584274 k-mer in 67229 contigs before removing low-coverage contigs.
# Removed 1457897 k-mer in 28927 low-coverage contigs.
# 20: Found 1584229 k-mer in 67278 contigs before removing low-coverage contigs.
# Removed 1456346 k-mer in 28888 low-coverage contigs.
# 13: Found 1581761 k-mer in 66703 contigs before removing low-coverage contigs.
# Removed 1456942 k-mer in 28761 low-coverage contigs.
# 5: Found 1581443 k-mer in 67200 contigs before removing low-coverage contigs.
# Removed 1454435 k-mer in 28858 low-coverage contigs.
# Found 37871466 k-mer in 1610290 contigs before removing low-coverage contigs.
# Removed 34835021 k-mer in 691777 low-coverage contigs.
# Splitting ambiguous branches...
# 18: Split 57643 ambigiuous branches.
# 0: Split 57977 ambigiuous branches.
# 2: Split 57713 ambigiuous branches.
# 9: Split 57275 ambigiuous branches.
# 1: Split 57415 ambigiuous branches.
# 16: Split 57450 ambigiuous branches.
# 3: Split 57446 ambigiuous branches.
# 21: Split 57293 ambigiuous branches.
# 22: Split 58089 ambigiuous branches.
# 11: Split 57300 ambigiuous branches.
# 10: Split 57053 ambigiuous branches.
# 12: Split 57755 ambigiuous branches.
# 17: Split 58008 ambigiuous branches.
# 15: Split 57701 ambigiuous branches.
# 23: Split 57842 ambigiuous branches.
# 6: Split 57971 ambigiuous branches.
# 4: Split 57932 ambigiuous branches.
# 14: Split 57642 ambigiuous branches.
# 13: Split 57938 ambigiuous branches.
# 20: Split 57779 ambigiuous branches.
# 19: Split 57396 ambigiuous branches.
# 7: Split 57794 ambigiuous branches.
# 8: Split 57318 ambigiuous branches.
# 5: Split 57824 ambigiuous branches.
# Split 1383554 ambiguous branches.
# Removed 34835021 marked k-mer.
# Eroding tips...
# 5: Eroded 6 tips.
# 20: Eroded 12 tips.
# 10: Eroded 4 tips.
# 15: Eroded 4 tips.
# 21: Eroded 9 tips.
# 1: Eroded 9 tips.
# 6: Eroded 12 tips.
# 3: Eroded 6 tips.
# 23: Eroded 6 tips.
# 19: Eroded 5 tips.
# 12: Eroded 18 tips.
# 2: Eroded 10 tips.
# 8: Eroded 14 tips.
# 18: Eroded 19 tips.
# 11: Eroded 14 tips.
# 14: Eroded 14 tips.
# 13: Eroded 16 tips.
# 7: Eroded 16 tips.
# 22: Eroded 15 tips.
# 0: Eroded 16 tips.
# 9: Eroded 12 tips.
# 17: Eroded 16 tips.
# 4: Eroded 24 tips.
# 16: Eroded 16 tips.
# 1: Eroded 91 tips.
# 15: Eroded 82 tips.
# 3: Eroded 80 tips.
# 18: Eroded 73 tips.
# 2: Eroded 83 tips.
# 9: Eroded 87 tips.
# 0: Eroded 79 tips.
# 20: Eroded 79 tips.
# 7: Eroded 59 tips.
# 8: Eroded 76 tips.
# 22: Eroded 70 tips.
# 19: Eroded 79 tips.
# 21: Eroded 81 tips.
# 4: Eroded 77 tips.
# 5: Eroded 92 tips.
# 13: Eroded 95 tips.
# 12: Eroded 79 tips.
# 11: Eroded 89 tips.
# 6: Eroded 88 tips.
# 14: Eroded 76 tips.
# 10: Eroded 66 tips.
# 17: Eroded 92 tips.
# 23: Eroded 75 tips.
# 16: Eroded 89 tips.
# Eroded 2230 tips.
# Pruning tips shorter than 1 bp...
# 5: Pruned 3 tips.
# 13: Pruned 0 tips.
# 10: Pruned 2 tips.
# 4: Pruned 0 tips.
# 12: Pruned 0 tips.
# 16: Pruned 2 tips.
# 21: Pruned 0 tips.
# 14: Pruned 0 tips.
# 23: Pruned 0 tips.
# 7: Pruned 0 tips.
# 22: Pruned 0 tips.
# 0: Pruned 0 tips.
# 2: Pruned 0 tips.
# 19: Pruned 1 tips.
# 11: Pruned 0 tips.
# 6: Pruned 0 tips.
# 18: Pruned 0 tips.
# 1: Pruned 0 tips.
# 9: Pruned 0 tips.
# 20: Pruned 0 tips.
# 3: Pruned 0 tips.
# 8: Pruned 1 tips.
# 17: Pruned 1 tips.
# 15: Pruned 0 tips.
# Pruned 10 k-mer in 10 tips.
# Pruning tips shorter than 2 bp...
# 12: Pruned 0 tips.
# 23: Pruned 2 tips.
# 3: Pruned 0 tips.
# 10: Pruned 0 tips.
# 17: Pruned 1 tips.
# 0: Pruned 0 tips.
# 5: Pruned 0 tips.
# 7: Pruned 0 tips.
# 19: Pruned 1 tips.
# 14: Pruned 0 tips.
# 21: Pruned 0 tips.
# 13: Pruned 1 tips.
# 4: Pruned 1 tips.
# 6: Pruned 0 tips.
# 9: Pruned 0 tips.
# 11: Pruned 2 tips.
# 20: Pruned 0 tips.
# 15: Pruned 2 tips.
# 16: Pruned 0 tips.
# 1: Pruned 1 tips.
# 2: Pruned 0 tips.
# 22: Pruned 2 tips.
# 8: Pruned 0 tips.
# 18: Pruned 0 tips.
# Pruned 18 k-mer in 13 tips.
# Pruning tips shorter than 4 bp...
# 10: Pruned 0 tips.
# 23: Pruned 0 tips.
# 13: Pruned 0 tips.
# 21: Pruned 2 tips.
# 11: Pruned 0 tips.
# 15: Pruned 1 tips.
# 22: Pruned 1 tips.
# 5: Pruned 0 tips.
# 18: Pruned 1 tips.
# 7: Pruned 1 tips.
# 8: Pruned 0 tips.
# 3: Pruned 1 tips.
# 16: Pruned 0 tips.
# 12: Pruned 0 tips.
# 14: Pruned 0 tips.
# 19: Pruned 0 tips.
# 17: Pruned 0 tips.
# 6: Pruned 0 tips.
# 2: Pruned 1 tips.
# 0: Pruned 2 tips.
# 4: Pruned 0 tips.
# 20: Pruned 1 tips.
# 9: Pruned 0 tips.
# 1: Pruned 1 tips.
# Pruned 36 k-mer in 12 tips.
# Pruning tips shorter than 8 bp...
# 10: Pruned 0 tips.
# 18: Pruned 0 tips.
# 15: Pruned 2 tips.
# 2: Pruned 2 tips.
# 23: Pruned 0 tips.
# 21: Pruned 1 tips.
# 1: Pruned 2 tips.
# 22: Pruned 3 tips.
# 8: Pruned 1 tips.
# 12: Pruned 2 tips.
# 6: Pruned 1 tips.
# 16: Pruned 3 tips.
# 0: Pruned 1 tips.
# 17: Pruned 0 tips.
# 5: Pruned 1 tips.
# 13: Pruned 0 tips.
# 14: Pruned 1 tips.
# 4: Pruned 0 tips.
# 19: Pruned 0 tips.
# 20: Pruned 1 tips.
# 3: Pruned 3 tips.
# 9: Pruned 1 tips.
# 7: Pruned 0 tips.
# 11: Pruned 2 tips.
# Pruned 141 k-mer in 27 tips.
# Pruning tips shorter than 16 bp...
# 7: Pruned 1 tips.
# 8: Pruned 2 tips.
# 2: Pruned 1 tips.
# 4: Pruned 3 tips.
# 11: Pruned 0 tips.
# 1: Pruned 2 tips.
# 0: Pruned 0 tips.
# 12: Pruned 1 tips.
# 13: Pruned 1 tips.
# 6: Pruned 1 tips.
# 22: Pruned 1 tips.
# 21: Pruned 1 tips.
# 19: Pruned 1 tips.
# 5: Pruned 1 tips.
# 23: Pruned 5 tips.
# 16: Pruned 3 tips.
# 17: Pruned 2 tips.
# 3: Pruned 1 tips.
# 15: Pruned 1 tips.
# 14: Pruned 1 tips.
# 10: Pruned 1 tips.
# 18: Pruned 0 tips.
# 20: Pruned 3 tips.
# 9: Pruned 1 tips.
# Pruned 346 k-mer in 34 tips.
# Pruning tips shorter than 32 bp...
# 10: Pruned 0 tips.
# 1: Pruned 1 tips.
# 23: Pruned 2 tips.
# 8: Pruned 3 tips.
# 22: Pruned 2 tips.
# 15: Pruned 1 tips.
# 13: Pruned 1 tips.
# 5: Pruned 2 tips.
# 11: Pruned 3 tips.
# 14: Pruned 1 tips.
# 20: Pruned 2 tips.
# 6: Pruned 2 tips.
# 2: Pruned 2 tips.
# 21: Pruned 2 tips.
# 7: Pruned 2 tips.
# 16: Pruned 2 tips.
# 12: Pruned 2 tips.
# 17: Pruned 2 tips.
# 4: Pruned 3 tips.
# 0: Pruned 4 tips.
# 3: Pruned 8 tips.
# 9: Pruned 2 tips.
# 19: Pruned 4 tips.
# 18: Pruned 2 tips.
# Pruned 1192 k-mer in 55 tips.
# Pruning tips shorter than 61 bp...
# 13: Pruned 0 tips.
# 22: Pruned 0 tips.
# 23: Pruned 0 tips.
# 5: Pruned 1 tips.
# 8: Pruned 1 tips.
# 11: Pruned 1 tips.
# 7: Pruned 1 tips.
# 10: Pruned 1 tips.
# 4: Pruned 2 tips.
# 2: Pruned 1 tips.
# 18: Pruned 2 tips.
# 15: Pruned 1 tips.
# 21: Pruned 1 tips.
# 17: Pruned 2 tips.
# 3: Pruned 2 tips.
# 20: Pruned 1 tips.
# 14: Pruned 0 tips.
# 0: Pruned 1 tips.
# 1: Pruned 2 tips.
# 6: Pruned 3 tips.
# 16: Pruned 2 tips.
# 19: Pruned 2 tips.
# 12: Pruned 5 tips.
# 9: Pruned 4 tips.
# Pruned 1598 k-mer in 36 tips.
# Pruning tips shorter than 61 bp...
# 6: Pruned 0 tips.
# 17: Pruned 0 tips.
# 20: Pruned 0 tips.
# 13: Pruned 0 tips.
# 19: Pruned 0 tips.
# 3: Pruned 0 tips.
# 16: Pruned 0 tips.
# 1: Pruned 0 tips.
# 4: Pruned 0 tips.
# 12: Pruned 0 tips.
# 10: Pruned 0 tips.
# 23: Pruned 0 tips.
# 22: Pruned 0 tips.
# 8: Pruned 0 tips.
# 21: Pruned 0 tips.
# 11: Pruned 0 tips.
# 5: Pruned 0 tips.
# 7: Pruned 0 tips.
# 18: Pruned 0 tips.
# 2: Pruned 0 tips.
# 9: Pruned 0 tips.
# 15: Pruned 0 tips.
# 14: Pruned 0 tips.
# 0: Pruned 0 tips.
# Pruned 187 tips in 7 rounds.
# Popping bubbles...
# 0: Removed 18 bubbles.
# 1: Removed 18 bubbles.
# 2: Removed 16 bubbles.
# 3: Removed 18 bubbles.
# 4: Removed 12 bubbles.
# 5: Removed 16 bubbles.
# 6: Removed 16 bubbles.
# 7: Removed 13 bubbles.
# 8: Removed 8 bubbles.
# 9: Removed 9 bubbles.
# 10: Removed 3 bubbles.
# 11: Removed 13 bubbles.
# 12: Removed 3 bubbles.
# 13: Removed 6 bubbles.
# 14: Removed 7 bubbles.
# 15: Removed 10 bubbles.
# 16: Removed 4 bubbles.
# 17: Removed 4 bubbles.
# 18: Removed 6 bubbles.
# 19: Removed 3 bubbles.
# 20: Removed 4 bubbles.
# 21: Removed 0 bubbles.
# 22: Removed 0 bubbles.
# 23: Removed 1 bubbles.
# Removed 208 bubbles.
# Removed 208 bubbles.
# Marking ambiguous branches...
# 6: Marked 34 edges of 16 ambiguous vertices.
# 1: Marked 42 edges of 20 ambiguous vertices.
# 23: Marked 41 edges of 20 ambiguous vertices.
# 13: Marked 29 edges of 14 ambiguous vertices.
# 18: Marked 37 edges of 18 ambiguous vertices.
# 20: Marked 29 edges of 14 ambiguous vertices.
# 4: Marked 48 edges of 24 ambiguous vertices.
# 2: Marked 29 edges of 14 ambiguous vertices.
# 10: Marked 40 edges of 20 ambiguous vertices.
# 12: Marked 43 edges of 21 ambiguous vertices.
# 14: Marked 36 edges of 18 ambiguous vertices.
# 11: Marked 24 edges of 12 ambiguous vertices.
# 22: Marked 35 edges of 17 ambiguous vertices.
# 3: Marked 48 edges of 23 ambiguous vertices.
# 19: Marked 35 edges of 17 ambiguous vertices.
# 5: Marked 44 edges of 22 ambiguous vertices.
# 8: Marked 39 edges of 19 ambiguous vertices.
# 0: Marked 34 edges of 17 ambiguous vertices.
# 7: Marked 28 edges of 14 ambiguous vertices.
# 16: Marked 51 edges of 25 ambiguous vertices.
# 17: Marked 28 edges of 14 ambiguous vertices.
# 15: Marked 37 edges of 18 ambiguous vertices.
# 21: Marked 40 edges of 20 ambiguous vertices.
# 9: Marked 66 edges of 33 ambiguous vertices.
# Marked 450 ambiguous branches.
# Assembling...
# 11: Assembled 39430 k-mer in 24 contigs.
# 17: Assembled 21489 k-mer in 24 contigs.
# 18: Assembled 54712 k-mer in 20 contigs.
# 10: Assembled 63967 k-mer in 29 contigs.
# 14: Assembled 71131 k-mer in 28 contigs.
# 12: Assembled 20992 k-mer in 29 contigs.
# 6: Assembled 93083 k-mer in 25 contigs.
# 13: Assembled 59811 k-mer in 21 contigs.
# 8: Assembled 162380 k-mer in 21 contigs.
# 5: Assembled 60725 k-mer in 23 contigs.
# 9: Assembled 183153 k-mer in 34 contigs.
# 7: Assembled 50420 k-mer in 20 contigs.
# 0: Assembled 178459 k-mer in 24 contigs.
# 16: Assembled 141722 k-mer in 36 contigs.
# 19: Assembled 126161 k-mer in 21 contigs.
# 23: Assembled 136459 k-mer in 34 contigs.
# 1: Assembled 224337 k-mer in 34 contigs.
# 2: Assembled 119261 k-mer in 22 contigs.
# 22: Assembled 195119 k-mer in 28 contigs.
# 3: Assembled 106296 k-mer in 28 contigs.
# 15: Assembled 270788 k-mer in 31 contigs.
# 21: Assembled 113306 k-mer in 27 contigs.
# 20: Assembled 381667 k-mer in 31 contigs.
# 4: Assembled 141770 k-mer in 34 contigs.
# Assembled 3016638 k-mer in 648 contigs.
# Concatenating fasta files to abyss-1.fa
# Concatenating fasta files to abyss-bubbles.fa
# Done.
# AdjList    -k61 -m50 --dot abyss-1.fa >abyss-1.dot
# abyss-filtergraph  --dot   -k61 -g abyss-2.dot1 abyss-1.dot abyss-1.fa >abyss-1.path
# MergeContigs --dot   -k61 -g abyss-2.dot -o abyss-2.fa abyss-1.fa abyss-2.dot1 abyss-1.path
# PopBubbles  --dot -j24 -k61  -p0.9  -g abyss-3.dot abyss-2.fa abyss-2.dot >abyss-2.path
# MergeContigs   -k61 -o abyss-3.fa abyss-2.fa abyss-2.dot abyss-2.path
# awk '!/^>/ {x[">" $1]=1; next} {getline s} $1 in x {print $0 "\n" s}' \
# 	abyss-2.path abyss-1.fa >abyss-indel.fa
# ln -sf abyss-3.fa abyss-unitigs.fa
# abyss-map   -j24 -l40    /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq abyss-3.fa \
# 	|abyss-fixmate   -l40  -h abyss-3.hist \
# 	|sort -snk3 -k4 \
# 	|DistanceEst   -j24 -k61  -l40 -s1000 -n10  -o abyss-3.dist abyss-3.hist
# Overlap  --dot   -k61 -g abyss-4.dot -o abyss-4.fa abyss-3.fa abyss-3.dot abyss-3.dist
# Overlap: 1
# Scaffold: 0
# No overlap: 0
# Insignificant (<5bp): 0
# Homopolymer: 0
# Motif: 0
# Ambiguous: 0
# SimpleGraph   -s1000 -n10  -j24 -k61 -o abyss-4.path1 abyss-4.dot abyss-3.dist
# Seed too short: 0
# Seeds with no edges: 0
# Edges removed: 0
# Total paths attempted: 274
# Unique path: 162
# No possible paths: 109
# No valid paths: 2
# Repetitive: 0
# Multiple valid paths: 1
# Too many solutions: 0
# Too complex: 0
#
# The minimum number of pairs in a distance estimate is 10.
# The minimum number of pairs used in a path is 10.
# abyss-index  --fai abyss-3.fa
# abyss-index  --fai abyss-4.fa
# cat abyss-3.fa.fai abyss-4.fa.fai \
# 	|MergePaths   -j24 -k61 -s1000  -o abyss-4.path2 - abyss-4.path1
# Ignored 0 paths whose seeds are shorter than 1000 bp.
# PathOverlap --assemble   -k61  abyss-4.dot abyss-4.path2 >abyss-4.path3
# cat abyss-3.fa abyss-4.fa \
# 	|PathConsensus  --dot -k61  -p0.9  -o abyss-5.path -s abyss-5.fa -g abyss-5.dot - abyss-4.dot abyss-4.path3
# cat abyss-3.fa abyss-4.fa abyss-5.fa |MergeContigs   -k61 -o abyss-6.fa - abyss-5.dot abyss-5.path
# ln -sf abyss-6.fa abyss-contigs.fa
# PathOverlap --overlap   -k61 --dot abyss-5.dot abyss-5.path >abyss-6.dot
# ln -sf abyss-6.dot abyss-contigs.dot
# abyss-map   -j24 -l40    /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq abyss-6.fa \
# 	|abyss-fixmate   -l40  -h abyss-6.hist \
# 	|sort -snk3 -k4 \
# 	|DistanceEst   --dot --mean -j24 -k61  -l40 -s1000 -n10  -o abyss-6.dist.dot abyss-6.hist
# abyss-scaffold    -k61 -s1000-10000 -n10 -g abyss-6.path.dot  abyss-6.dot abyss-6.dist.dot >abyss-6.path
# PathConsensus  --dot -k61  -p0.9  -s abyss-7.fa -g abyss-7.dot -o abyss-7.path abyss-6.fa abyss-6.dot abyss-6.path
# cat abyss-6.fa abyss-7.fa \
# 	|MergeContigs   -k61 -o abyss-8.fa - abyss-7.dot abyss-7.path
# ln -sf abyss-8.fa abyss-scaffolds.fa
# PathOverlap --overlap   -k61 --dot abyss-7.dot abyss-7.path >abyss-8.dot
# ln -sf abyss-8.dot abyss-scaffolds.dot
# abyss-fac   abyss-unitigs.fa abyss-contigs.fa abyss-scaffolds.fa |tee abyss-stats.tab
# n	n:500	L50	min	N80	N50	N20	E-size	max	sum	name
# 386	151	17	501	18302	47884	127859	65489	157763	3001362	abyss-unitigs.fa
# 282	91	11	501	32193	93105	164133	101286	278946	3107797	abyss-contigs.fa
# 273	83	10	501	39815	114121	164905	111962	278946	3107719	abyss-scaffolds.fa
# ln -sf abyss-stats.tab abyss-stats
# tr '\t' , <abyss-stats.tab >abyss-stats.csv
# abyss-tabtomd abyss-stats.tab >abyss-stats.md
# pandoc abyss-stats.md >abyss-stats.html

# %% [markdown]
# ## run velvet

# %%
if not os.path.exists('velvet'):
    os.mkdir('velvet')
os.chdir('velvet')

# %%
os.getcwd()
# Out:
# '/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/velvet'

# %%
command_line = '''{VELVETH} . {bestkmer} -separate -fastq -shortPaired {read1} {read2} '''.format( \
               VELVETH = VELVETH, bestkmer=bestkmer, outfolder = outfolder, thread = thread, \
               read1 = os.path.join(outfolder,'Trimmomatic','read1.pair.fq'), read2 = os.path.join(outfolder,'Trimmomatic','read2.pair.fq'))
print(command_line)
result = subprocess.check_output(command_line, shell=True)
# Out:
# /home/p/anaconda/anaconda3_5.2.0/bin/velveth . 61 -separate -fastq -shortPaired /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq

# %%
result = result.decode('utf-8')
print(result)
# Out:
# [0.000000] Reading FastQ file /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq;
# [0.000053] Reading FastQ file /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq;
# [73.855966] 19695418 sequences found in total in the paired sequence files
# [73.855972] Done
# [73.874804] Reading read set file ./Sequences;
# [78.061765] 19695418 sequences found
# [96.199030] Done
# [96.199033] 19695418 sequences in total.
# [96.199078] Writing into roadmap file ./Roadmaps...
# [125.001654] Inputting sequences...
# [125.012275] Inputting sequence 0 / 19695418
# [127.018804] Inputting sequence 14000000 / 19695418
# [128.189542] Inputting sequence 5000000 / 19695418
# [130.099874] Inputting sequence 19000000 / 19695418
# [131.392979] Inputting sequence 10000000 / 19695418
# [132.537936] Inputting sequence 1000000 / 19695418
# [135.368511] Inputting sequence 15000000 / 19695418
# [136.250908] Inputting sequence 6000000 / 19695418
# [139.221170] Inputting sequence 11000000 / 19695418
# [140.185788] Inputting sequence 2000000 / 19695418
# [142.850568] Inputting sequence 16000000 / 19695418
# [143.629966] Inputting sequence 7000000 / 19695418
# [146.861881] Inputting sequence 12000000 / 19695418
# [148.775898] Inputting sequence 3000000 / 19695418
# [151.156600] Inputting sequence 17000000 / 19695418
# [151.852703] Inputting sequence 8000000 / 19695418
# [154.606351] Inputting sequence 13000000 / 19695418
# [156.805598] Inputting sequence 4000000 / 19695418
# [158.142798] Inputting sequence 18000000 / 19695418
# [161.211133] Inputting sequence 9000000 / 19695418
# [162.445865]  === Sequences loaded in 37.444340 s
# [162.446827] Done inputting sequences
# [162.446893] Destroying splay table
# [163.471140] Splay table destroyed

# %%
command_line = '''{VELVETG} .  -exp_cov auto -cov_cutoff auto '''.format( VELVETG = VELVETG)
print(command_line)
result = subprocess.check_output(command_line, shell=True)
# Out:
# /home/p/anaconda/anaconda3_5.2.0/bin/velvetg .  -exp_cov auto -cov_cutoff auto

# %%
result = result.decode('utf-8')
print(result)
os.chdir('..')
# Out:
# [0.000000] Reading roadmap file ./Roadmaps
# [27.580867] 19695418 roadmaps read
# [27.596294] Creating insertion markers
# [34.005227] Ordering insertion markers
# [35.643671] Counting preNodes
# [39.000879] 5973749 preNodes counted, creating them now
# [43.344941] Sequence 1000000 / 19695418
# [47.595644] Sequence 2000000 / 19695418
# [51.771762] Sequence 3000000 / 19695418
# [55.746266] Sequence 4000000 / 19695418
# [60.079233] Sequence 5000000 / 19695418
# [63.994490] Sequence 6000000 / 19695418
# [67.916661] Sequence 7000000 / 19695418
# [71.940916] Sequence 8000000 / 19695418
# [75.886416] Sequence 9000000 / 19695418
# [79.999447] Sequence 10000000 / 19695418
# [83.882210] Sequence 11000000 / 19695418
# [87.755178] Sequence 12000000 / 19695418
# [91.761211] Sequence 13000000 / 19695418
# [96.171603] Sequence 14000000 / 19695418
# [100.460566] Sequence 15000000 / 19695418
# [104.717268] Sequence 16000000 / 19695418
# [108.804571] Sequence 17000000 / 19695418
# [112.947955] Sequence 18000000 / 19695418
# [117.227555] Sequence 19000000 / 19695418
# [119.854399] Adjusting marker info...
# [123.987706] Connecting preNodes
# [124.828216] Connecting 5000000 / 19695418
# [125.493482] Connecting 10000000 / 19695418
# [125.976913] Connecting 15000000 / 19695418
# [128.310854] Connecting 3000000 / 19695418
# [128.897890] Connecting 8000000 / 19695418
# [129.412827] Connecting 13000000 / 19695418
# [129.885050] Connecting 18000000 / 19695418
# [132.018264] Connecting 1000000 / 19695418
# [132.266004] Connecting 6000000 / 19695418
# [133.594483] Connecting 11000000 / 19695418
# [133.897803] Connecting 16000000 / 19695418
# [136.634692] Connecting 4000000 / 19695418
# [137.362946] Connecting 9000000 / 19695418
# [137.948132] Connecting 14000000 / 19695418
# [138.640469] Connecting 19000000 / 19695418
# [140.950410] Connecting 2000000 / 19695418
# [141.336544] Connecting 7000000 / 19695418
# [142.686674] Connecting 12000000 / 19695418
# [143.446775] Connecting 17000000 / 19695418
# [145.916455] Cleaning up memory
# [146.086971] Done creating preGraph
# [146.086992] Concatenation...
# [149.102069] Renumbering preNodes
# [149.102077] Initial preNode count 5973749
# [149.437812] Destroyed 2913185 preNodes
# [149.437815] Concatenation over!
# [149.437816] Clipping short tips off preGraph
# [150.274774] Concatenation...
# [151.118251] Renumbering preNodes
# [151.118255] Initial preNode count 3060564
# [151.330721] Destroyed 1369741 preNodes
# [151.330724] Concatenation over!
# [151.330725] 821896 tips cut off
# [151.330725] 1690823 nodes left
# [151.330778] Writing into pregraph file ./PreGraph...
# [157.926449] Reading read set file ./Sequences;
# [161.876149] 19695418 sequences found
# [180.203999] Done
# [210.542656] Reading pre-graph file ./PreGraph
# [210.547680] Graph has 1690823 nodes and 19695418 sequences
# [214.331161] Scanning pre-graph file ./PreGraph for k-mers
# [216.903523] 38982239 kmers found
# [223.205011] Sorting kmer occurence table ...
# [250.897259] Sorting done.
# [250.897267] Computing acceleration table...
# [251.220139] Computing offsets...
# [251.655569] Ghost Threading through reads 0 / 19695418
# [255.573451] Ghost Threading through reads 14000000 / 19695418
# [256.649540] Ghost Threading through reads 5000000 / 19695418
# [261.101903] Ghost Threading through reads 19000000 / 19695418
# [263.076510] Ghost Threading through reads 10000000 / 19695418
# [263.229482] Ghost Threading through reads 1000000 / 19695418
# [267.085543] Ghost Threading through reads 15000000 / 19695418
# [267.903953] Ghost Threading through reads 6000000 / 19695418
# [272.601032] Ghost Threading through reads 11000000 / 19695418
# [273.768627] Ghost Threading through reads 2000000 / 19695418
# [278.364547] Ghost Threading through reads 16000000 / 19695418
# [279.367549] Ghost Threading through reads 7000000 / 19695418
# [282.920414] Ghost Threading through reads 12000000 / 19695418
# [283.744935] Ghost Threading through reads 3000000 / 19695418
# [289.398866] Ghost Threading through reads 17000000 / 19695418
# [290.564832] Ghost Threading through reads 8000000 / 19695418
# [296.190894] Ghost Threading through reads 13000000 / 19695418
# [296.252517] Ghost Threading through reads 4000000 / 19695418
# [299.175319] Ghost Threading through reads 18000000 / 19695418
# [300.371045] Ghost Threading through reads 9000000 / 19695418
# [306.950201]  === Ghost-Threaded in 55.298062 s
# [306.950323] Threading through reads 0 / 19695418
# [313.291055] Threading through reads 14000000 / 19695418
# [315.196540] Threading through reads 5000000 / 19695418
# [319.140353] Threading through reads 19000000 / 19695418
# [321.137710] Threading through reads 10000000 / 19695418
# [323.219635] Threading through reads 1000000 / 19695418
# [326.736698] Threading through reads 15000000 / 19695418
# [329.182195] Threading through reads 6000000 / 19695418
# [335.835499] Threading through reads 11000000 / 19695418
# [337.656661] Threading through reads 2000000 / 19695418
# [341.647527] Threading through reads 16000000 / 19695418
# [342.692551] Threading through reads 7000000 / 19695418
# [349.018607] Threading through reads 12000000 / 19695418
# [351.513643] Threading through reads 3000000 / 19695418
# [355.297664] Threading through reads 17000000 / 19695418
# [357.299616] Threading through reads 8000000 / 19695418
# [363.900064] Threading through reads 13000000 / 19695418
# [364.092295] Threading through reads 4000000 / 19695418
# [370.096463] Threading through reads 18000000 / 19695418
# [370.098303] Threading through reads 9000000 / 19695418
# [374.473369]  === Threaded in 67.523156 s
# [421.126286] Correcting graph with cutoff 0.200000
# [421.354338] Determining eligible starting points
# [424.167845] Done listing starting nodes
# [424.167850] Initializing todo lists
# [424.849330] Done with initilization
# [424.849333] Activating arc lookup table
# [426.450473] Done activating arc lookup table
# [426.840379] 10000 / 1690823 nodes visited
# [427.386106] 20000 / 1690823 nodes visited
# [427.903083] 30000 / 1690823 nodes visited
# [428.429216] 40000 / 1690823 nodes visited
# [428.966965] 50000 / 1690823 nodes visited
# [429.530333] 60000 / 1690823 nodes visited
# [430.185899] 70000 / 1690823 nodes visited
# [430.787305] 80000 / 1690823 nodes visited
# [431.424606] 90000 / 1690823 nodes visited
# [431.956872] 100000 / 1690823 nodes visited
# [432.473826] 110000 / 1690823 nodes visited
# [432.970712] 120000 / 1690823 nodes visited
# [433.352679] 130000 / 1690823 nodes visited
# [433.699025] 140000 / 1690823 nodes visited
# [434.092772] 150000 / 1690823 nodes visited
# [434.449488] 160000 / 1690823 nodes visited
# [434.932847] 170000 / 1690823 nodes visited
# [435.423484] 180000 / 1690823 nodes visited
# [435.957694] 190000 / 1690823 nodes visited
# [436.455587] 200000 / 1690823 nodes visited
# [436.963538] 210000 / 1690823 nodes visited
# [437.436750] 220000 / 1690823 nodes visited
# [437.894380] 230000 / 1690823 nodes visited
# [438.302467] 240000 / 1690823 nodes visited
# [438.725989] 250000 / 1690823 nodes visited
# [439.153151] 260000 / 1690823 nodes visited
# [439.578455] 270000 / 1690823 nodes visited
# [440.013908] 280000 / 1690823 nodes visited
# [440.456285] 290000 / 1690823 nodes visited
# [440.914423] 300000 / 1690823 nodes visited
# [441.369811] 310000 / 1690823 nodes visited
# [441.833085] 320000 / 1690823 nodes visited
# [442.273340] 330000 / 1690823 nodes visited
# [442.733505] 340000 / 1690823 nodes visited
# [443.172153] 350000 / 1690823 nodes visited
# [443.610244] 360000 / 1690823 nodes visited
# [444.079275] 370000 / 1690823 nodes visited
# [444.543316] 380000 / 1690823 nodes visited
# [445.011759] 390000 / 1690823 nodes visited
# [445.494385] 400000 / 1690823 nodes visited
# [445.989732] 410000 / 1690823 nodes visited
# [446.454779] 420000 / 1690823 nodes visited
# [446.948821] 430000 / 1690823 nodes visited
# [447.426976] 440000 / 1690823 nodes visited
# [447.918461] 450000 / 1690823 nodes visited
# [448.393040] 460000 / 1690823 nodes visited
# [448.886462] 470000 / 1690823 nodes visited
# [449.391026] 480000 / 1690823 nodes visited
# [449.882970] 490000 / 1690823 nodes visited
# [450.368717] 500000 / 1690823 nodes visited
# [450.892375] 510000 / 1690823 nodes visited
# [451.396857] 520000 / 1690823 nodes visited
# [451.880343] 530000 / 1690823 nodes visited
# [452.373969] 540000 / 1690823 nodes visited
# [452.850144] 550000 / 1690823 nodes visited
# [453.337992] 560000 / 1690823 nodes visited
# [453.823058] 570000 / 1690823 nodes visited
# [454.322662] 580000 / 1690823 nodes visited
# [454.815704] 590000 / 1690823 nodes visited
# [455.287327] 600000 / 1690823 nodes visited
# [455.740237] 610000 / 1690823 nodes visited
# [456.191879] 620000 / 1690823 nodes visited
# [456.662927] 630000 / 1690823 nodes visited
# [457.151787] 640000 / 1690823 nodes visited
# [457.610856] 650000 / 1690823 nodes visited
# [458.051506] 660000 / 1690823 nodes visited
# [458.481964] 670000 / 1690823 nodes visited
# [458.927007] 680000 / 1690823 nodes visited
# [459.378664] 690000 / 1690823 nodes visited
# [459.833493] 700000 / 1690823 nodes visited
# [460.359183] 710000 / 1690823 nodes visited
# [460.853018] 720000 / 1690823 nodes visited
# [461.305105] 730000 / 1690823 nodes visited
# [461.800045] 740000 / 1690823 nodes visited
# [462.260087] 750000 / 1690823 nodes visited
# [462.721074] 760000 / 1690823 nodes visited
# [463.224969] 770000 / 1690823 nodes visited
# [463.722306] 780000 / 1690823 nodes visited
# [464.197066] 790000 / 1690823 nodes visited
# [464.697498] 800000 / 1690823 nodes visited
# [465.204005] 810000 / 1690823 nodes visited
# [465.722395] 820000 / 1690823 nodes visited
# [466.231405] 830000 / 1690823 nodes visited
# [466.733954] 840000 / 1690823 nodes visited
# [467.226764] 850000 / 1690823 nodes visited
# [467.736952] 860000 / 1690823 nodes visited
# [468.240873] 870000 / 1690823 nodes visited
# [468.734583] 880000 / 1690823 nodes visited
# [469.235012] 890000 / 1690823 nodes visited
# [469.718146] 900000 / 1690823 nodes visited
# [470.218134] 910000 / 1690823 nodes visited
# [470.721531] 920000 / 1690823 nodes visited
# [471.213506] 930000 / 1690823 nodes visited
# [471.732167] 940000 / 1690823 nodes visited
# [472.245261] 950000 / 1690823 nodes visited
# [472.758610] 960000 / 1690823 nodes visited
# [473.281921] 970000 / 1690823 nodes visited
# [473.801056] 980000 / 1690823 nodes visited
# [474.319150] 990000 / 1690823 nodes visited
# [474.854599] 1000000 / 1690823 nodes visited
# [475.396433] 1010000 / 1690823 nodes visited
# [475.921876] 1020000 / 1690823 nodes visited
# [476.424550] 1030000 / 1690823 nodes visited
# [476.970947] 1040000 / 1690823 nodes visited
# [477.490951] 1050000 / 1690823 nodes visited
# [478.038211] 1060000 / 1690823 nodes visited
# [478.577795] 1070000 / 1690823 nodes visited
# [479.110847] 1080000 / 1690823 nodes visited
# [479.641178] 1090000 / 1690823 nodes visited
# [480.211390] 1100000 / 1690823 nodes visited
# [480.765182] 1110000 / 1690823 nodes visited
# [481.332920] 1120000 / 1690823 nodes visited
# [481.877403] 1130000 / 1690823 nodes visited
# [482.410578] 1140000 / 1690823 nodes visited
# [482.951434] 1150000 / 1690823 nodes visited
# [483.493172] 1160000 / 1690823 nodes visited
# [484.035249] 1170000 / 1690823 nodes visited
# [484.567690] 1180000 / 1690823 nodes visited
# [485.074593] 1190000 / 1690823 nodes visited
# [485.613418] 1200000 / 1690823 nodes visited
# [486.170953] 1210000 / 1690823 nodes visited
# [486.746449] 1220000 / 1690823 nodes visited
# [487.246689] 1230000 / 1690823 nodes visited
# [487.783840] 1240000 / 1690823 nodes visited
# [488.312897] 1250000 / 1690823 nodes visited
# [488.852060] 1260000 / 1690823 nodes visited
# [489.399105] 1270000 / 1690823 nodes visited
# [489.924091] 1280000 / 1690823 nodes visited
# [490.461704] 1290000 / 1690823 nodes visited
# [490.973969] 1300000 / 1690823 nodes visited
# [491.491506] 1310000 / 1690823 nodes visited
# [492.009515] 1320000 / 1690823 nodes visited
# [492.557323] 1330000 / 1690823 nodes visited
# [493.103386] 1340000 / 1690823 nodes visited
# [493.632234] 1350000 / 1690823 nodes visited
# [494.134523] 1360000 / 1690823 nodes visited
# [494.677778] 1370000 / 1690823 nodes visited
# [495.188361] 1380000 / 1690823 nodes visited
# [495.733040] 1390000 / 1690823 nodes visited
# [496.280793] 1400000 / 1690823 nodes visited
# [496.834147] 1410000 / 1690823 nodes visited
# [497.400502] 1420000 / 1690823 nodes visited
# [497.970464] 1430000 / 1690823 nodes visited
# [498.508693] 1440000 / 1690823 nodes visited
# [499.102706] 1450000 / 1690823 nodes visited
# [499.709250] 1460000 / 1690823 nodes visited
# [500.286210] 1470000 / 1690823 nodes visited
# [500.913237] 1480000 / 1690823 nodes visited
# [501.540581] 1490000 / 1690823 nodes visited
# [502.136721] 1500000 / 1690823 nodes visited
# [502.697595] 1510000 / 1690823 nodes visited
# [503.266712] 1520000 / 1690823 nodes visited
# [503.824615] 1530000 / 1690823 nodes visited
# [504.385105] 1540000 / 1690823 nodes visited
# [504.925898] 1550000 / 1690823 nodes visited
# [505.526476] 1560000 / 1690823 nodes visited
# [506.098489] 1570000 / 1690823 nodes visited
# [506.682585] 1580000 / 1690823 nodes visited
# [507.202281] 1590000 / 1690823 nodes visited
# [507.692319] 1600000 / 1690823 nodes visited
# [508.149193] 1610000 / 1690823 nodes visited
# [508.554327] 1620000 / 1690823 nodes visited
# [508.931824] 1630000 / 1690823 nodes visited
# [509.328165] 1640000 / 1690823 nodes visited
# [509.655629] 1650000 / 1690823 nodes visited
# [509.906291] 1660000 / 1690823 nodes visited
# [509.992776] 1670000 / 1690823 nodes visited
# [510.021991] 1680000 / 1690823 nodes visited
# [510.051073] 1690000 / 1690823 nodes visited
# [510.083679] 1700000 / 1690823 nodes visited
# [510.116094] 1710000 / 1690823 nodes visited
# [510.144361] 1720000 / 1690823 nodes visited
# [510.145872] Concatenation...
# [510.227979] Renumbering nodes
# [510.227982] Initial node count 1690823
# [510.252529] Removed 1408896 null nodes
# [510.252532] Concatenation over!
# [510.252533] Clipping short tips off graph, drastic
# [510.458286] Concatenation...
# [513.084725] Renumbering nodes
# [513.084730] Initial node count 281927
# [513.112268] Removed 120696 null nodes
# [513.112270] Concatenation over!
# [513.112271] 161231 nodes left
# [513.112454] Writing into graph file ./Graph2...
# [528.521190] Measuring median coverage depth...
# [528.669977] Median coverage depth = 388.227723
# [528.670044] Removing contigs with coverage < 194.113861...
# [528.848363] Concatenation...
# [615.104137] Renumbering nodes
# [615.104145] Initial node count 161231
# [615.104509] Removed 160666 null nodes
# [615.104511] Concatenation over!
# [615.104540] Concatenation...
# [615.104653] Renumbering nodes
# [615.104654] Initial node count 565
# [615.104655] Removed 0 null nodes
# [615.104655] Concatenation over!
# [615.104661] Clipping short tips off graph, drastic
# [615.104677] Concatenation...
# [615.107712] Renumbering nodes
# [615.107713] Initial node count 565
# [615.107720] Removed 4 null nodes
# [615.107720] Concatenation over!
# [615.107721] 561 nodes left
# [615.107724] Read coherency...
# [615.107731] Identifying unique nodes
# [615.107741] Done, 163 unique nodes counted
# [615.107741] Trimming read tips
# [615.107762] Renumbering nodes
# [615.107762] Initial node count 561
# [615.107763] Removed 0 null nodes
# [615.107764] Confronted to 0 multiple hits and 0 null over 0
# [615.107764] Read coherency over!
# [615.223088] Starting pebble resolution...
# [615.498099] Computing read to node mapping array sizes
# [616.238381] Computing read to node mappings
# [617.328016] Estimating library insert lengths...
# [618.900733] Paired-end library 1 has length: 326, sample standard deviation: 63
# [618.900743] Done
# [618.900943] Computing direct node to node mappings
# [619.849108] Scaffolding node 0
# [619.967202]  === Nodes Scaffolded in 1.066258 s
# [620.261066] Preparing to correct graph with cutoff 0.200000
# [620.633037] Cleaning memory
# [620.633050] Deactivating local correction settings
# [620.633093] Pebble done.
# [620.633094] Starting pebble resolution...
# [620.751781] Computing read to node mapping array sizes
# [621.194398] Computing read to node mappings
# [622.212133] Estimating library insert lengths...
# [623.663897] Paired-end library 1 has length: 326, sample standard deviation: 63
# [623.663904] Done
# [623.664032] Computing direct node to node mappings
# [624.424624] Scaffolding node 0
# [624.487887]  === Nodes Scaffolded in 0.823853 s
# [624.636280] Preparing to correct graph with cutoff 0.200000
# [624.637392] Cleaning memory
# [624.637394] Deactivating local correction settings
# [624.637423] Pebble done.
# [624.637429] Concatenation...
# [624.703633] Renumbering nodes
# [624.703636] Initial node count 561
# [624.703682] Removed 186 null nodes
# [624.703685] Concatenation over!
# [624.703686] Removing reference contigs with coverage < 194.113861...
# [624.703705] Concatenation...
# [624.703751] Renumbering nodes
# [624.703751] Initial node count 375
# [624.703752] Removed 0 null nodes
# [624.703754] Concatenation over!
# [624.880129] Writing contigs into ./contigs.fa...
# [630.612550] Writing into stats file ./stats.txt...
# [630.738173] Writing into graph file ./LastGraph...
# [634.276858] Estimated Coverage = 388.227723
# [634.276863] Estimated Coverage cutoff = 194.113861
# Final graph has 375 nodes and n50 of 90990, max 434471, total 3018656, using 19253629/19695418 reads

# %% [markdown]
# ## run SPAdes

# %%
if not os.path.exists('spades'):
    os.mkdir('spades')
os.chdir('spades')

# %%
os.getcwd()
# Out:
# '/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades'

# %%
command_line = '''{SPADES} --pe1-1 {read1} --pe1-2  {read2} -t {thread} -o .  '''.format( \
               SPADES = SPADES, bestkmer=bestkmer, outfolder = outfolder, thread = thread, \
               read1 = os.path.join(outfolder,'Trimmomatic','read1.pair.fq'), read2 = os.path.join(outfolder,'Trimmomatic','read2.pair.fq'))
print(command_line)
result = subprocess.check_output(command_line, shell=True)
# Out:
# /home/p/anaconda/anaconda3_5.2.0/bin/spades.py --pe1-1 /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq --pe1-2  /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq -t 24 -o .

# %%
result = result.decode('utf-8')
print(result)
os.chdir('..')
# Out:
# Command line: /home/p/anaconda/anaconda3_5.2.0/bin/spades.py	--pe1-1	/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq	--pe1-2	/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq	-t	24	-o	/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades
#
# System information:
#   SPAdes version: 3.12.0
#   Python version: 3.6.4
#   OS: Linux-3.10.0-862.6.3.el7.x86_64-x86_64-with-centos-7.5.1804-Core
#
# Output dir: /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Multi-cell mode (you should set '--sc' flag if input data was obtained with MDA (single-cell) technology or --meta flag if processing metagenomic dataset)
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
#       left reads: ['/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq']
#       right reads: ['/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq']
#       interlaced reads: not specified
#       single reads: not specified
#       merged reads: not specified
# Read error correction parameters:
#   Iterations: 1
#   PHRED offset will be auto-detected
#   Corrected reads will be compressed
# Assembly parameters:
#   k: automatic selection based on read length
#   Repeat resolution is enabled
#   Mismatch careful mode is turned OFF
#   MismatchCorrector will be SKIPPED
#   Coverage cutoff is turned OFF
# Other parameters:
#   Dir for temp files: /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/tmp
#   Threads: 24
#   Memory limit (in Gb): 62
#
#
# ======= SPAdes pipeline started. Log can be found here: /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/spades.log
#
#
# ===== Read error correction started.
#
#
# == Running read error correction tool: /home/p/anaconda/anaconda3_5.2.0/share/spades-3.12.0-1/bin/spades-hammer /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/corrected/configs/config.info
#
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  75)   Starting BayesHammer, built from N/A, git revision N/A
#   0:00:00.001     4M / 4M    INFO    General                 (main.cpp                  :  76)   Loading config from /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/corrected/configs/config.info
#   0:00:00.004     4M / 4M    INFO    General                 (main.cpp                  :  78)   Maximum # of threads to use (adjusted due to OMP capabilities): 24
#   0:00:00.004     4M / 4M    INFO    General                 (memory_limit.cpp          :  49)   Memory limit set to 62 Gb
#   0:00:00.004     4M / 4M    INFO    General                 (main.cpp                  :  86)   Trying to determine PHRED offset
#   0:00:00.004     4M / 4M    INFO    General                 (main.cpp                  :  92)   Determined value is 33
#   0:00:00.004     4M / 4M    INFO    General                 (hammer_tools.cpp          :  36)   Hamming graph threshold tau=1, k=21, subkmer positions = [ 0 10 ]
#   0:00:00.004     4M / 4M    INFO    General                 (main.cpp                  : 113)   Size of aux. kmer data 24 bytes
#      === ITERATION 0 begins ===
#   0:00:00.005     4M / 4M    INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:00:00.005     4M / 4M    INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 384 files using 24 threads. This might take a while.
#   0:00:00.006     4M / 4M    INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1024
#   0:00:00.006     4M / 4M    INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 0.861057 Gb
#   0:00:00.006     4M / 4M    INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 174762
#   0:00:00.147    13G / 13G   INFO   K-mer Splitting          (kmer_data.cpp             :  97)   Processing /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq
#   0:00:24.896    13G / 13G   INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 5135636 reads
#   0:00:47.573    13G / 13G   INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 9847709 reads
#   0:00:47.574    13G / 13G   INFO   K-mer Splitting          (kmer_data.cpp             :  97)   Processing /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq
#   0:01:14.368    13G / 13G   INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 15410538 reads
#   0:01:34.696    13G / 13G   INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 19695418 reads
#   0:01:34.696    13G / 13G   INFO   K-mer Splitting          (kmer_data.cpp             : 112)   Total 19695418 reads processed
#   0:01:36.527    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:01:37.517    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 116316938 kmers in total.
#   0:01:37.517    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:01:38.792    96M / 13G   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 314)   Building perfect hash indices
#   0:01:41.077   100M / 13G   INFO    General                 (kmer_index_builder.hpp    : 150)   Merging final buckets.
#   0:01:42.796   100M / 13G   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 336)   Index built. Total 53944440 bytes occupied (3.71017 bits per kmer).
#   0:01:42.797   100M / 13G   INFO   K-mer Counting           (kmer_data.cpp             : 356)   Arranging kmers in hash map order
#   0:01:46.626     1G / 13G   INFO    General                 (main.cpp                  : 148)   Clustering Hamming graph.
#   0:03:16.623     1G / 13G   INFO    General                 (main.cpp                  : 155)   Extracting clusters
#   0:04:27.165     1G / 13G   INFO    General                 (main.cpp                  : 167)   Clustering done. Total clusters: 20625902
#   0:04:27.288   984M / 13G   INFO   K-mer Counting           (kmer_data.cpp             : 376)   Collecting K-mer information, this takes a while.
#   0:04:28.883     3G / 13G   INFO   K-mer Counting           (kmer_data.cpp             : 382)   Processing /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq
#   0:05:53.822     3G / 13G   INFO   K-mer Counting           (kmer_data.cpp             : 382)   Processing /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq
#   0:07:14.289     3G / 13G   INFO   K-mer Counting           (kmer_data.cpp             : 389)   Collection done, postprocessing.
#   0:07:14.745     3G / 13G   INFO   K-mer Counting           (kmer_data.cpp             : 403)   There are 116316938 kmers in total. Among them 78944844 (67.8705%) are singletons.
#   0:07:14.746     3G / 13G   INFO    General                 (main.cpp                  : 173)   Subclustering Hamming graph
#   0:07:28.942     3G / 13G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 649)   Subclustering done. Total 19 non-read kmers were generated.
#   0:07:28.942     3G / 13G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 650)   Subclustering statistics:
#   0:07:28.942     3G / 13G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 651)     Total singleton hamming clusters: 14680360. Among them 3737586 (25.4598%) are good
#   0:07:28.942     3G / 13G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 652)     Total singleton subclusters: 28843. Among them 28823 (99.9307%) are good
#   0:07:28.942     3G / 13G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 653)     Total non-singleton subcluster centers: 6249577. Among them 6110130 (97.7687%) are good
#   0:07:28.942     3G / 13G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 654)     Average size of non-trivial subcluster: 16.263 kmers
#   0:07:28.942     3G / 13G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 655)     Average number of sub-clusters per non-singleton cluster: 1.05599
#   0:07:28.942     3G / 13G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 656)     Total solid k-mers: 9876539
#   0:07:28.942     3G / 13G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 657)     Substitution probabilities: [4,4]((0.931926,0.044178,0.0047499,0.019146),(0.0257645,0.96702,0.00295413,0.00426175),(0.00422791,0.00293985,0.967003,0.0258295),(0.0191177,0.00472561,0.0441311,0.932026))
#   0:07:28.976     3G / 13G   INFO    General                 (main.cpp                  : 178)   Finished clustering.
#   0:07:28.976     3G / 13G   INFO    General                 (main.cpp                  : 197)   Starting solid k-mers expansion in 24 threads.
#   0:08:28.524     3G / 13G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 0 produced 405497 new k-mers.
#   0:09:28.276     3G / 13G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 1 produced 29799 new k-mers.
#   0:10:28.327     3G / 13G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 2 produced 1022 new k-mers.
#   0:11:28.760     3G / 13G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 3 produced 104 new k-mers.
#   0:12:28.994     3G / 13G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 4 produced 12 new k-mers.
#   0:13:29.196     3G / 13G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 5 produced 0 new k-mers.
#   0:13:29.196     3G / 13G   INFO    General                 (main.cpp                  : 222)   Solid k-mers finalized
#   0:13:29.196     3G / 13G   INFO    General                 (hammer_tools.cpp          : 220)   Starting read correction in 24 threads.
#   0:13:29.196     3G / 13G   INFO    General                 (hammer_tools.cpp          : 233)   Correcting pair of reads: /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq and /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq
#   0:13:40.702     5G / 13G   INFO    General                 (hammer_tools.cpp          : 168)   Prepared batch 0 of 2400000 reads.
#   0:13:55.859     6G / 13G   INFO    General                 (hammer_tools.cpp          : 175)   Processed batch 0
#   0:14:00.512     6G / 13G   INFO    General                 (hammer_tools.cpp          : 185)   Written batch 0
#   0:14:10.671     6G / 13G   INFO    General                 (hammer_tools.cpp          : 168)   Prepared batch 1 of 2400000 reads.
#   0:14:26.981     6G / 13G   INFO    General                 (hammer_tools.cpp          : 175)   Processed batch 1
#   0:14:31.674     6G / 13G   INFO    General                 (hammer_tools.cpp          : 185)   Written batch 1
#   0:14:41.446     6G / 13G   INFO    General                 (hammer_tools.cpp          : 168)   Prepared batch 2 of 2400000 reads.
#   0:14:56.901     6G / 13G   INFO    General                 (hammer_tools.cpp          : 175)   Processed batch 2
#   0:15:02.032     6G / 13G   INFO    General                 (hammer_tools.cpp          : 185)   Written batch 2
#   0:15:12.957     6G / 13G   INFO    General                 (hammer_tools.cpp          : 168)   Prepared batch 3 of 2400000 reads.
#   0:15:28.704     6G / 13G   INFO    General                 (hammer_tools.cpp          : 175)   Processed batch 3
#   0:15:34.592     6G / 13G   INFO    General                 (hammer_tools.cpp          : 185)   Written batch 3
#   0:15:35.619     6G / 13G   INFO    General                 (hammer_tools.cpp          : 168)   Prepared batch 4 of 247709 reads.
#   0:15:37.564     6G / 13G   INFO    General                 (hammer_tools.cpp          : 175)   Processed batch 4
#   0:15:38.099     6G / 13G   INFO    General                 (hammer_tools.cpp          : 185)   Written batch 4
#   0:15:40.354     3G / 13G   INFO    General                 (hammer_tools.cpp          : 274)   Correction done. Changed 4834273 bases in 3366769 reads.
#   0:15:40.354     3G / 13G   INFO    General                 (hammer_tools.cpp          : 275)   Failed to correct 2402 bases out of 2887288194.
#   0:15:40.998    96M / 13G   INFO    General                 (main.cpp                  : 255)   Saving corrected dataset description to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/corrected/corrected.yaml
#   0:15:40.998    96M / 13G   INFO    General                 (main.cpp                  : 262)   All done. Exiting.
#
# == Compressing corrected reads (with pigz)
#
# == Dataset description file was created: /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/corrected/corrected.yaml
#
#
# ===== Read error correction finished.
#
#
# ===== Assembling started.
#
#
# == Running assembler: K21
#
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  74)   Loaded config from /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/K21/configs/config.info
#   0:00:00.000     4M / 4M    INFO    General                 (memory_limit.cpp          :  49)   Memory limit set to 62 Gb
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  87)   Starting SPAdes, built from N/A, git revision N/A
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  88)   Maximum k-mer length: 128
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  89)   Assembling dataset (/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/dataset.info) with K=21
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  90)   Maximum # of threads to use (adjusted due to OMP capabilities): 24
#   0:00:00.000     4M / 4M    INFO    General                 (launch.hpp                :  51)   SPAdes started
#   0:00:00.000     4M / 4M    INFO    General                 (launch.hpp                :  58)   Starting from stage: construction
#   0:00:00.000     4M / 4M    INFO    General                 (launch.hpp                :  65)   Two-step RR enabled: 0
#   0:00:00.001     4M / 4M    INFO   StageManager             (stage.cpp                 : 132)   STAGE == de Bruijn graph construction
#   0:00:00.002     4M / 4M    INFO    General                 (read_converter.hpp        :  77)   Converting reads to binary format for library #0 (takes a while)
#   0:00:00.002     4M / 4M    INFO    General                 (read_converter.hpp        :  78)   Converting paired reads
#   0:00:00.342    80M / 80M   INFO    General                 (binary_converter.hpp      :  93)   16384 reads processed
#   0:00:00.583    96M / 96M   INFO    General                 (binary_converter.hpp      :  93)   32768 reads processed
#   0:00:01.006   128M / 128M  INFO    General                 (binary_converter.hpp      :  93)   65536 reads processed
#   0:00:01.711   188M / 188M  INFO    General                 (binary_converter.hpp      :  93)   131072 reads processed
#   0:00:03.204   308M / 308M  INFO    General                 (binary_converter.hpp      :  93)   262144 reads processed
#   0:00:06.185   548M / 548M  INFO    General                 (binary_converter.hpp      :  93)   524288 reads processed
#   0:00:15.289   920M / 920M  INFO    General                 (binary_converter.hpp      :  93)   1048576 reads processed
#   0:00:29.531   920M / 920M  INFO    General                 (binary_converter.hpp      :  93)   2097152 reads processed
#   0:00:57.933   924M / 924M  INFO    General                 (binary_converter.hpp      :  93)   4194304 reads processed
#   0:01:57.702   932M / 932M  INFO    General                 (binary_converter.hpp      :  93)   8388608 reads processed
#   0:02:18.168   720M / 932M  INFO    General                 (binary_converter.hpp      : 117)   9842709 reads written
#   0:02:18.793     4M / 932M  INFO    General                 (read_converter.hpp        :  87)   Converting single reads
#   0:02:18.931   200M / 932M  INFO    General                 (binary_converter.hpp      : 117)   4800 reads written
#   0:02:18.944     4M / 932M  INFO    General                 (read_converter.hpp        :  95)   Converting merged reads
#   0:02:19.050   196M / 932M  INFO    General                 (binary_converter.hpp      : 117)   0 reads written
#   0:02:19.062     4M / 932M  INFO    General                 (construction.cpp          : 111)   Max read length 150
#   0:02:19.062     4M / 932M  INFO    General                 (construction.cpp          : 117)   Average read length 146.615
#   0:02:19.062     4M / 932M  INFO    General                 (stage.cpp                 : 101)   PROCEDURE == k+1-mer counting
#   0:02:19.064     4M / 932M  INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 576 files using 24 threads. This might take a while.
#   0:02:19.065     4M / 932M  INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1024
#   0:02:19.065     4M / 932M  INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 0.861057 Gb
#   0:02:19.065     4M / 932M  INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 116508
#   0:02:33.482    13G / 13G   INFO    General                 (kmer_splitters.hpp        : 289)   Processed 24309926 reads
#   0:02:41.882    13G / 13G   INFO    General                 (kmer_splitters.hpp        : 289)   Processed 39380436 reads
#   0:02:41.882    13G / 13G   INFO    General                 (kmer_splitters.hpp        : 295)   Adding contigs from previous K
#   0:02:43.436    96M / 13G   INFO    General                 (kmer_splitters.hpp        : 308)   Used 39380436 reads
#   0:02:43.436    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:02:43.726    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 9972070 kmers in total.
#   0:02:43.727    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:02:43.868    96M / 13G   INFO    General                 (stage.cpp                 : 101)   PROCEDURE == Extension index construction
#   0:02:43.868    96M / 13G   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:02:43.868    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 384 files using 24 threads. This might take a while.
#   0:02:43.868    96M / 13G   INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1024
#   0:02:43.868    96M / 13G   INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 0.859809 Gb
#   0:02:43.868    96M / 13G   INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 174762
#   0:02:44.433    13G / 13G   INFO    General                 (kmer_splitters.hpp        : 380)   Processed 9972070 kmers
#   0:02:44.433    13G / 13G   INFO    General                 (kmer_splitters.hpp        : 385)   Used 9972070 kmers.
#   0:02:44.580    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:02:44.694    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 9957107 kmers in total.
#   0:02:44.695    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:02:44.801    96M / 13G   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 314)   Building perfect hash indices
#   0:02:45.075    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 150)   Merging final buckets.
#   0:02:45.179    96M / 13G   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 336)   Index built. Total 4625512 bytes occupied (3.71635 bits per kmer).
#   0:02:45.187   108M / 13G   INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build:  99)   Building k-mer extensions from k+1-mers
#   0:02:45.520   108M / 13G   INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build: 103)   Building k-mer extensions from k+1-mers finished.
#   0:02:45.521   108M / 13G   INFO    General                 (stage.cpp                 : 101)   PROCEDURE == Early tip clipping
#   0:02:45.521   108M / 13G   INFO    General                 (construction.cpp          : 253)   Early tip clipper length bound set as (RL - K)
#   0:02:45.521   108M / 13G   INFO   Early tip clipping       (early_simplification.hpp  : 181)   Early tip clipping
#   0:02:45.930   108M / 13G   INFO   Early tip clipping       (early_simplification.hpp  : 184)   990930 22-mers were removed by early tip clipper
#   0:02:45.930   108M / 13G   INFO    General                 (stage.cpp                 : 101)   PROCEDURE == Condensing graph
#   0:02:45.932   108M / 13G   INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 355)   Extracting unbranching paths
#   0:02:46.183   116M / 13G   INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 374)   Extracting unbranching paths finished. 173120 sequences extracted
#   0:02:46.358   116M / 13G   INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 310)   Collecting perfect loops
#   0:02:46.459   116M / 13G   INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 343)   Collecting perfect loops finished. 272 loops collected
#   0:02:46.549   116M / 13G   INFO    General                 (stage.cpp                 : 101)   PROCEDURE == Filling coverage indices (PHM)
#   0:02:46.549   116M / 13G   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:02:46.549   116M / 13G   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 314)   Building perfect hash indices
#   0:02:46.679   116M / 13G   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 336)   Index built. Total 4636616 bytes occupied (3.71968 bits per kmer).
#   0:02:46.707   156M / 13G   INFO    General                 (construction.cpp          : 388)   Collecting k-mer coverage information from reads, this takes a while.
#   0:03:15.566   156M / 13G   INFO    General                 (construction.cpp          : 508)   Filling coverage and flanking coverage from PHM
#   0:03:15.817   156M / 13G   INFO    General                 (construction.cpp          : 464)   Processed 346631 edges
#   0:03:15.863   104M / 13G   INFO   StageManager             (stage.cpp                 : 132)   STAGE == EC Threshold Finding
#   0:03:15.865   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 181)   Kmer coverage valley at: 8
#   0:03:15.865   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 201)   K-mer histogram maximum: 785
#   0:03:15.865   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 237)   Estimated median coverage: 785. Coverage mad: 106.747
#   0:03:15.865   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 259)   Fitting coverage model
#   0:03:16.515   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 295)   ... iteration 2
#   0:03:18.167   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 295)   ... iteration 4
#   0:03:23.969   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 295)   ... iteration 8
#   0:03:28.921   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 309)   Fitted mean coverage: 766.355. Fitted coverage std. dev: 96.658
#   0:03:28.949   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 334)   Probability of erroneous kmer at valley: 1
#   0:03:28.949   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 358)   Preliminary threshold calculated as: 463
#   0:03:28.949   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 362)   Threshold adjusted to: 387
#   0:03:28.949   104M / 13G   INFO    General                 (kmer_coverage_model.cpp   : 375)   Estimated genome size (ignoring repeats): 3000542
#   0:03:28.949   104M / 13G   INFO    General                 (genomic_info_filler.cpp   : 112)   Mean coverage was calculated as 766.355
#   0:03:28.949   104M / 13G   INFO    General                 (genomic_info_filler.cpp   : 127)   EC coverage threshold value was calculated as 387
#   0:03:28.949   104M / 13G   INFO    General                 (genomic_info_filler.cpp   : 128)   Trusted kmer low bound: 0
#   0:03:28.949   104M / 13G   INFO   StageManager             (stage.cpp                 : 132)   STAGE == Raw Simplification
#   0:03:28.952   104M / 13G   INFO    General                 (simplification.cpp        : 128)   PROCEDURE == InitialCleaning
#   0:03:28.954   104M / 13G   INFO    General                 (graph_simplification.hpp  : 662)   Flanking coverage based disconnection disabled
#   0:03:28.954   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Self conjugate edge remover
#   0:03:28.979   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Self conjugate edge remover triggered 0 times
#   0:03:28.979   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Initial tip clipper
#   0:03:29.020   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Initial tip clipper triggered 992 times
#   0:03:29.020   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Initial ec remover
#   0:03:29.604   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Initial ec remover triggered 30972 times
#   0:03:29.604   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Initial isolated edge remover
#   0:03:29.699   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Initial isolated edge remover triggered 25673 times
#   0:03:29.703   104M / 13G   INFO   StageManager             (stage.cpp                 : 132)   STAGE == Simplification
#   0:03:29.704   104M / 13G   INFO    General                 (simplification.cpp        : 357)   Graph simplification started
#   0:03:29.704   104M / 13G   INFO    General                 (graph_simplification.hpp  : 634)   Creating parallel br instance
#   0:03:29.704   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 1
#   0:03:29.704   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:29.710   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 179 times
#   0:03:29.710   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.156   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 10237 times
#   0:03:30.156   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.292   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 5828 times
#   0:03:30.292   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 2
#   0:03:30.292   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.294   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 16 times
#   0:03:30.294   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 338 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 6 times
#   0:03:30.321   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 3
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 1 times
#   0:03:30.321   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 4
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 5
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 6
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 7
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 8
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 9
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 1 times
#   0:03:30.321   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 10
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 5 times
#   0:03:30.321   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 11
#   0:03:30.321   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.323   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.323   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.333   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 2 times
#   0:03:30.333   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.337   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 0 times
#   0:03:30.337   104M / 13G   INFO    General                 (simplification.cpp        : 362)   PROCEDURE == Simplification cycle, iteration 12
#   0:03:30.337   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.337   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.337   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.337   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.337   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:03:30.337   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 0 times
#   0:03:30.337   104M / 13G   INFO   StageManager             (stage.cpp                 : 132)   STAGE == Simplification Cleanup
#   0:03:30.337   104M / 13G   INFO    General                 (simplification.cpp        : 196)   PROCEDURE == Post simplification
#   0:03:30.337   104M / 13G   INFO    General                 (graph_simplification.hpp  : 453)   Disconnection of relatively low covered edges disabled
#   0:03:30.337   104M / 13G   INFO    General                 (graph_simplification.hpp  : 489)   Complex tip clipping disabled
#   0:03:30.338   104M / 13G   INFO    General                 (graph_simplification.hpp  : 634)   Creating parallel br instance
#   0:03:30.338   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.339   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.339   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.346   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.346   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:03:30.348   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:03:30.348   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:03:30.355   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:03:30.355   104M / 13G   INFO    General                 (simplification.cpp        : 330)   Disrupting self-conjugate edges
#   0:03:30.361   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 165)   Running Removing isolated edges
#   0:03:30.362   104M / 13G   INFO   Simplification           (parallel_processing.hpp   : 167)   Removing isolated edges triggered 35 times
#   0:03:30.362   104M / 13G   INFO    General                 (simplification.cpp        : 470)   Counting average coverage
#   0:03:30.365   104M / 13G   INFO    General                 (simplification.cpp        : 476)   Average coverage = 515.215
#   0:03:30.365   104M / 13G   INFO   StageManager             (stage.cpp                 : 132)   STAGE == Contig Output
#   0:03:30.366   104M / 13G   INFO    General                 (contig_output_stage.cpp   :  40)   Writing GFA to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/assembly_graph_with_scaffolds.gfa
#   0:03:30.427   104M / 13G   INFO    General                 (contig_output.hpp         :  22)   Outputting contigs to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/before_rr.fasta
#   0:03:30.512   104M / 13G   INFO    General                 (contig_output_stage.cpp   :  51)   Outputting FastG graph to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/assembly_graph.fastg
#   0:03:30.747   104M / 13G   INFO    General                 (contig_output.hpp         :  22)   Outputting contigs to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/simplified_contigs.fasta
#   0:03:30.836   104M / 13G   INFO    General                 (contig_output.hpp         :  22)   Outputting contigs to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/final_contigs.fasta
#   0:03:30.924   104M / 13G   INFO   StageManager             (stage.cpp                 : 132)   STAGE == Contig Output
#   0:03:30.924   104M / 13G   INFO    General                 (contig_output_stage.cpp   :  40)   Writing GFA to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/assembly_graph_with_scaffolds.gfa
#   0:03:30.986   104M / 13G   INFO    General                 (contig_output.hpp         :  22)   Outputting contigs to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/before_rr.fasta
#   0:03:31.072   104M / 13G   INFO    General                 (contig_output_stage.cpp   :  51)   Outputting FastG graph to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/assembly_graph.fastg
#   0:03:31.312   104M / 13G   INFO    General                 (contig_output.hpp         :  22)   Outputting contigs to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/simplified_contigs.fasta
#   0:03:31.400   104M / 13G   INFO    General                 (contig_output.hpp         :  22)   Outputting contigs to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K21/final_contigs.fasta
#   0:03:31.487   104M / 13G   INFO    General                 (launch.hpp                : 149)   SPAdes finished
#   0:03:31.528    96M / 13G   INFO    General                 (main.cpp                  : 109)   Assembling time: 0 hours 3 minutes 31 seconds
# Max read length detected as 150
# Default k-mer sizes were set to [21, 33, 55, 77] because estimated read length (150) is equal to or greater than 150
#
# == Running assembler: K33
#
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  74)   Loaded config from /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/K33/configs/config.info
#   0:00:00.000     4M / 4M    INFO    General                 (memory_limit.cpp          :  49)   Memory limit set to 62 Gb
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  87)   Starting SPAdes, built from N/A, git revision N/A
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  88)   Maximum k-mer length: 128
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  89)   Assembling dataset (/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/dataset.info) with K=33
#   0:00:00.000     4M / 4M    INFO    General                 (main.cpp                  :  90)   Maximum # of threads to use (adjusted due to OMP capabilities): 24
#   0:00:00.000     4M / 4M    INFO    General                 (launch.hpp                :  51)   SPAdes started
#   0:00:00.000     4M / 4M    INFO    General                 (launch.hpp                :  58)   Starting from stage: construction
#   0:00:00.000     4M / 4M    INFO    General                 (launch.hpp                :  65)   Two-step RR enabled: 0
#   0:00:00.000     4M / 4M    INFO   StageManager             (stage.cpp                 : 132)   STAGE == de Bruijn graph construction
#   0:00:00.001     4M / 4M    INFO    General                 (read_converter.hpp        :  59)   Binary reads detected
#   0:00:00.003     4M / 4M    INFO    General                 (construction.cpp          : 111)   Max read length 150
#   0:00:00.003     4M / 4M    INFO    General                 (construction.cpp          : 117)   Average read length 146.615
#   0:00:00.003     4M / 4M    INFO    General                 (stage.cpp                 : 101)   PROCEDURE == k+1-mer counting
#   0:00:00.003     4M / 4M    INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 576 files using 24 threads. This might take a while.
#   0:00:00.003     4M / 4M    INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1024
#   0:00:00.003     4M / 4M    INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 0.861057 Gb
#   0:00:00.003     4M / 4M    INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 58254
#   0:00:11.480    13G / 13G   INFO    General                 (kmer_splitters.hpp        : 289)   Processed 13544415 reads
#   0:00:23.676    13G / 13G   INFO    General                 (kmer_splitters.hpp        : 289)   Processed 27060386 reads
#   0:00:34.616    13G / 13G   INFO    General                 (kmer_splitters.hpp        : 289)   Processed 39380436 reads
#   0:00:34.616    13G / 13G   INFO    General                 (kmer_splitters.hpp        : 295)   Adding contigs from previous K
#   0:00:36.938    96M / 13G   INFO    General                 (kmer_splitters.hpp        : 308)   Used 39380436 reads
#   0:00:36.938    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:00:38.022    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 10045941 kmers in total.
#   0:00:38.022    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:00:38.283    96M / 13G   INFO    General                 (stage.cpp                 : 101)   PROCEDURE == Extension index construction
#   0:00:38.283    96M / 13G   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:00:38.283    96M / 13G   INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 384 files using 24 threads. This might take a while.
# ...
#   0:01:47.709   676M / 13G   INFO    General                 (pair_info_count.cpp       : 209)   Edge pairs: 67108864 (rough upper limit)
#   0:01:47.709   676M / 13G   INFO    General                 (pair_info_count.cpp       : 213)   5988163 paired reads (60.8386% of all) aligned to long edges
#   0:01:47.753   276M / 13G   INFO    General                 (pair_info_count.cpp       : 354)     Insert size = 328.079, deviation = 63.1472, left quantile = 249, right quantile = 408, read length = 150
#   0:01:47.861   468M / 13G   INFO    General                 (pair_info_count.cpp       : 371)   Filtering data for library #0
#   0:01:47.862   468M / 13G   INFO    General                 (pair_info_count.cpp       :  39)   Selecting usual mapper
#   0:01:50.941   468M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 200000 reads
#   0:01:51.011   472M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 400000 reads
#   0:01:51.021   472M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 600000 reads
#   0:01:51.025   472M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 800000 reads
#   0:01:51.042   468M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 1000000 reads
#   0:01:51.043   468M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 1200000 reads
#   0:01:51.066   468M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 2200000 reads
#   0:01:51.112   468M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 4200000 reads
#   0:01:54.395   468M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 8400000 reads
#   0:01:54.569   468M / 13G   INFO    General                 (sequence_mapper_notifier.h:  98)   Total 9842709 reads processed
#   0:01:54.569   468M / 13G   INFO    General                 (pair_info_count.cpp       : 383)   Mapping library #0
#   0:01:54.569   468M / 13G   INFO    General                 (pair_info_count.cpp       : 385)   Mapping paired reads (takes a while)
#   0:01:54.569   468M / 13G   INFO    General                 (pair_info_count.cpp       : 289)   Left insert size quantile 249, right insert size quantile 408, filtering threshold 2, rounding threshold 0
#   0:01:54.581   480M / 13G   INFO    General                 (pair_info_count.cpp       :  39)   Selecting usual mapper
#   0:01:57.289   492M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 200000 reads
#   0:01:57.300   492M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 400000 reads
#   0:01:57.311   492M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 600000 reads
#   0:01:57.315   492M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 800000 reads
#   0:01:57.316   492M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 1000000 reads
#   0:01:57.319   492M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 1200000 reads
#   0:01:57.330   492M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 2200000 reads
#   0:01:57.369   492M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 4200000 reads
#   0:02:00.146   500M / 13G   INFO    General                 (sequence_mapper_notifier.h:  80)   Processed 8400000 reads
#   0:02:00.356   500M / 13G   INFO    General                 (sequence_mapper_notifier.h:  98)   Total 9842709 reads processed
#   0:02:00.391   296M / 13G   INFO   StageManager             (stage.cpp                 : 132)   STAGE == Distance Estimation
#   0:02:00.391   296M / 13G   INFO    General                 (distance_estimation.cpp   : 173)   Processing library #0
#   0:02:00.391   296M / 13G   INFO    General                 (distance_estimation.cpp   : 149)   Weight Filter Done
#   0:02:00.391   296M / 13G   INFO   DistanceEstimator        (distance_estimation.hpp   : 116)   Using SIMPLE distance estimator
#   0:02:00.409   300M / 13G   INFO    General                 (distance_estimation.cpp   :  34)   Filtering info
#   0:02:00.409   300M / 13G   INFO    General                 (pair_info_filters.hpp     : 242)   Start filtering; index size: 17400
#   0:02:00.421   300M / 13G   INFO    General                 (pair_info_filters.hpp     : 263)   Done filtering
#   0:02:00.421   300M / 13G   INFO    General                 (distance_estimation.cpp   : 156)   Refining clustered pair information
#   0:02:00.423   300M / 13G   INFO    General                 (distance_estimation.cpp   : 158)   The refining of clustered pair information has been finished
#   0:02:00.423   300M / 13G   INFO    General                 (distance_estimation.cpp   : 160)   Improving paired information
#   0:02:00.461   328M / 13G   INFO   PairInfoImprover         (pair_info_improver.hpp    : 103)   Paired info stats: missing = 101; contradictional = 18
#   0:02:00.507   328M / 13G   INFO   PairInfoImprover         (pair_info_improver.hpp    : 103)   Paired info stats: missing = 0; contradictional = 0
#   0:02:00.507   328M / 13G   INFO    General                 (distance_estimation.cpp   : 103)   Filling scaffolding index
#   0:02:00.507   328M / 13G   INFO   DistanceEstimator        (distance_estimation.hpp   : 116)   Using SMOOTHING distance estimator
#   0:02:00.525   360M / 13G   INFO    General                 (distance_estimation.cpp   :  34)   Filtering info
#   0:02:00.525   360M / 13G   INFO    General                 (pair_info_filters.hpp     : 242)   Start filtering; index size: 12946
#   0:02:00.530   360M / 13G   INFO    General                 (pair_info_filters.hpp     : 263)   Done filtering
#   0:02:00.530   360M / 13G   INFO    General                 (distance_estimation.cpp   : 182)   Clearing raw paired index
#   0:02:00.532   360M / 13G   INFO   StageManager             (stage.cpp                 : 132)   STAGE == Repeat Resolving
#   0:02:00.533   360M / 13G   INFO    General                 (repeat_resolving.cpp      :  69)   Using Path-Extend repeat resolving
#   0:02:00.533   360M / 13G   INFO    General                 (launcher.cpp              : 477)   ExSPAnder repeat resolving tool started
#   0:02:00.557   384M / 13G   INFO    General                 (launcher.cpp              : 392)   Creating main extenders, unique edge length = 2000
#   0:02:00.558   384M / 13G   INFO    General                 (extenders_logic.cpp       : 275)   Estimated coverage of library #0 is 332.88
#   0:02:00.559   384M / 13G   INFO    General                 (extenders_logic.cpp       : 275)   Estimated coverage of library #0 is 332.88
#   0:02:00.565   384M / 13G   INFO    General                 (extenders_logic.cpp       : 472)   Using 1 paired-end library
#   0:02:00.565   384M / 13G   INFO    General                 (extenders_logic.cpp       : 473)   Using 1 paired-end scaffolding library
#   0:02:00.565   384M / 13G   INFO    General                 (extenders_logic.cpp       : 474)   Using 0 single read libraries
#   0:02:00.565   384M / 13G   INFO    General                 (launcher.cpp              : 420)   Total number of extenders is 3
#   0:02:00.565   384M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 0 paths from 5912 (0%)
#   0:02:00.649   388M / 13G   INFO    General                 (path_extender.hpp         : 883)   Processed 128 paths from 5912 (2%)
#   0:02:00.657   388M / 13G   INFO    General                 (path_extender.hpp         : 883)   Processed 256 paths from 5912 (4%)
#   0:02:00.671   392M / 13G   INFO    General                 (path_extender.hpp         : 883)   Processed 512 paths from 5912 (8%)
#   0:02:00.675   392M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 592 paths from 5912 (10%)
#   0:02:00.690   396M / 13G   INFO    General                 (path_extender.hpp         : 883)   Processed 1024 paths from 5912 (17%)
#   0:02:00.696   396M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 1184 paths from 5912 (20%)
#   0:02:00.716   400M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 1776 paths from 5912 (30%)
#   0:02:00.726   404M / 13G   INFO    General                 (path_extender.hpp         : 883)   Processed 2048 paths from 5912 (34%)
#   0:02:00.737   404M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 2368 paths from 5912 (40%)
#   0:02:00.757   412M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 2960 paths from 5912 (50%)
#   0:02:00.778   416M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 3552 paths from 5912 (60%)
#   0:02:00.797   420M / 13G   INFO    General                 (path_extender.hpp         : 883)   Processed 4096 paths from 5912 (69%)
#   0:02:00.799   420M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 4144 paths from 5912 (70%)
#   0:02:00.819   424M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 4736 paths from 5912 (80%)
#   0:02:00.839   432M / 13G   INFO    General                 (path_extender.hpp         : 885)   Processed 5328 paths from 5912 (90%)
#   0:02:00.861   436M / 13G   INFO    General                 (launcher.cpp              : 234)   Finalizing paths
#   0:02:00.861   436M / 13G   INFO    General                 (launcher.cpp              : 236)   Deduplicating paths
#   0:02:00.873   432M / 13G   INFO    General                 (launcher.cpp              : 240)   Paths deduplicated
#   0:02:00.873   432M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 295)   Removing overlaps
#   0:02:00.873   432M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 298)   Sorting paths
#   0:02:00.875   432M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 305)   Marking overlaps
#   0:02:00.875   432M / 13G   INFO   OverlapRemover           (pe_resolver.hpp           : 130)   Marking start/end overlaps
#   0:02:00.881   432M / 13G   INFO   OverlapRemover           (pe_resolver.hpp           : 133)   Marking remaining overlaps
#   0:02:00.888   432M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 308)   Splitting paths
#   0:02:00.889   432M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 313)   Deduplicating paths
#   0:02:00.892   432M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 315)   Overlaps removed
#   0:02:00.899   432M / 13G   INFO    General                 (launcher.cpp              : 257)   Paths finalized
#   0:02:00.899   432M / 13G   INFO    General                 (launcher.cpp              : 427)   Closing gaps in paths
#   0:02:00.917   436M / 13G   INFO    General                 (launcher.cpp              : 455)   Gap closing completed
#   0:02:00.923   436M / 13G   INFO    General                 (launcher.cpp              : 286)   Traversing tandem repeats
#   0:02:00.950   436M / 13G   INFO    General                 (launcher.cpp              : 296)   Traversed 3 loops
#   0:02:00.950   436M / 13G   INFO    General                 (launcher.cpp              : 234)   Finalizing paths
#   0:02:00.950   436M / 13G   INFO    General                 (launcher.cpp              : 236)   Deduplicating paths
#   0:02:00.952   436M / 13G   INFO    General                 (launcher.cpp              : 240)   Paths deduplicated
#   0:02:00.952   436M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 295)   Removing overlaps
#   0:02:00.952   436M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 298)   Sorting paths
#   0:02:00.953   436M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 305)   Marking overlaps
#   0:02:00.953   436M / 13G   INFO   OverlapRemover           (pe_resolver.hpp           : 130)   Marking start/end overlaps
#   0:02:00.958   436M / 13G   INFO   OverlapRemover           (pe_resolver.hpp           : 133)   Marking remaining overlaps
#   0:02:00.963   436M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 308)   Splitting paths
#   0:02:00.963   436M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 313)   Deduplicating paths
#   0:02:00.965   436M / 13G   INFO   PEResolver               (pe_resolver.hpp           : 315)   Overlaps removed
#   0:02:00.971   436M / 13G   INFO    General                 (launcher.cpp              : 257)   Paths finalized
#   0:02:00.992   436M / 13G   INFO    General                 (launcher.cpp              : 529)   ExSPAnder repeat resolving tool finished
#   0:02:01.014   408M / 13G   INFO   StageManager             (stage.cpp                 : 132)   STAGE == Contig Output
#   0:02:01.014   408M / 13G   INFO    General                 (contig_output_stage.cpp   :  40)   Writing GFA to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K77/assembly_graph_with_scaffolds.gfa
#   0:02:01.068   408M / 13G   INFO    General                 (contig_output.hpp         :  22)   Outputting contigs to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K77/before_rr.fasta
#   0:02:01.136   408M / 13G   INFO    General                 (contig_output_stage.cpp   :  51)   Outputting FastG graph to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K77/assembly_graph.fastg
#   0:02:01.357   408M / 13G   INFO    General                 (contig_output_stage.cpp   :  20)   Outputting FastG paths to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K77/final_contigs.paths
#   0:02:01.455   408M / 13G   INFO    General                 (contig_output_stage.cpp   :  20)   Outputting FastG paths to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades//K77/scaffolds.paths
#   0:02:01.551   408M / 13G   INFO    General                 (launch.hpp                : 149)   SPAdes finished
#   0:02:01.891    96M / 13G   INFO    General                 (main.cpp                  : 109)   Assembling time: 0 hours 2 minutes 1 seconds
#
# ===== Assembling finished. Used k-mer sizes: 21, 33, 55, 77
#
#  * Corrected reads are in /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/corrected/
#  * Assembled contigs are in /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/contigs.fasta
#  * Assembled scaffolds are in /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/scaffolds.fasta
#  * Assembly graph is in /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/assembly_graph.fastg
#  * Assembly graph in GFA format is in /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/assembly_graph_with_scaffolds.gfa
#  * Paths in the assembly graph corresponding to the contigs are in /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/contigs.paths
#  * Paths in the assembly graph corresponding to the scaffolds are in /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/scaffolds.paths
#
# ======= SPAdes pipeline finished.
#
# SPAdes log can be found here: /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/spades/spades.log
#
# Thank you for using SPAdes!

# %% [markdown]
# ## run IDBA-UD

# %%
if not os.path.exists('IDBA-UD'):
    os.mkdir('IDBA-UD')
os.chdir('IDBA-UD')

# %%
command_line = '''{FQ2FA} --merge --filter {read1} {read2} idba-paired-contigs.fa '''.format( \
               FQ2FA = FQ2FA, bestkmer=bestkmer, outfolder = outfolder, thread = thread, \
               read1 = os.path.join(outfolder,'Trimmomatic','read1.pair.fq'), read2 = os.path.join(outfolder,'Trimmomatic','read2.pair.fq'))
print(command_line)
result = subprocess.check_output(command_line, shell=True)
result = result.decode('utf-8')
print(result)
# Out:
# /home/p/anaconda/anaconda3_5.2.0/bin/fq2fa --merge --filter /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read1.pair.fq /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/Trimmomatic/read2.pair.fq idba-paired-contigs.fa

# %%
command_line = '''{IDBA_UD} -r idba-paired-contigs.fa --num_threads {thread} -o . '''.format( \
               IDBA_UD = IDBA_UD, bestkmer=bestkmer, outfolder = outfolder, thread = thread, \
               read1 = os.path.join(outfolder,'Trimmomatic','read1.pair.fq'), read2 = os.path.join(outfolder,'Trimmomatic','read2.pair.fq'))
print(command_line)
result = subprocess.check_output(command_line, shell=True)
result = result.decode('utf-8')
print(result)
# Out:
# /home/p/anaconda/anaconda3_5.2.0/bin/idba_ud -r idba-paired-contigs.fa --num_threads 24 -o .
# number of threads 24
# reads 19664504
# long reads 0
# extra reads 0
# read_length 150
# kmer 20
# kmers 19062498 19607055
# merge bubble 1157
# contigs: 42009 n50: 484 max: 5656 mean: 102 total length: 4296420 n80: 39
# aligned 12876007 reads
# confirmed bases: 2292413 correct reads: 10615469 bases: 2384891
# distance mean 321.22 sd 60.0233
# seed contigs 4003 local contigs 84018
# kmer 40
# kmers 15609138 15859200
# merge bubble 3070
# contigs: 6916 n50: 17629 max: 118926 mean: 504 total length: 3490265 n80: 3298
# aligned 18304412 reads
# confirmed bases: 2944690 correct reads: 17798623 bases: 1672150
# distance mean 327.924 sd 60.7581
# seed contigs 710 local contigs 13832
# kmer 60
# kmers 10003157 9872370
# merge bubble 309
# contigs: 2512 n50: 46939 max: 157761 mean: 1311 total length: 3295257 n80: 12857
# aligned 18877725 reads
# confirmed bases: 2994720 correct reads: 18409104 bases: 155576
# distance mean 328.138 sd 60.8018
# seed contigs 499 local contigs 5024
# kmer 80
# kmers 5328852 5327523
# merge bubble 11
# contigs: 1108 n50: 91088 max: 278317 mean: 2879 total length: 3190742 n80: 23970
# aligned 19121338 reads
# confirmed bases: 3013056 correct reads: 18584813 bases: 48226
# distance mean 328.184 sd 60.81
# seed contigs 372 local contigs 2216
# kmer 100
# kmers 4074696 4074530
# merge bubble 22
# contigs: 610 n50: 94757 max: 341997 mean: 5157 total length: 3146227 n80: 27309
# reads 19664504
# aligned 19184941 reads
# distance mean 328.225 sd 60.8083
# expected coverage 6.27307
# edgs 131
# contigs: 590 n50: 125076 max: 434655 mean: 5329 total length: 3144210 n80: 33077

# %%
os.chdir('..')

# %% [markdown]
# ## run soapdenovo

# %%
if not os.path.exists('soapdenovo'):
    os.mkdir('soapdenovo')
os.chdir('soapdenovo')

# %%
fw=open('myconfig','w')
fw.write('max_rd_len=150\n[LIB]\navg_ins=350\nreverse_seq=0\nasm_flags=3\nq1={read1}\nq2={read2}\n'.format(\
        read1 = os.path.join(outfolder,'Trimmomatic','read1.pair.fq'), read2 = os.path.join(outfolder,'Trimmomatic','read2.pair.fq')))
fw.close()

# %%
command_line = '''{SOAPDENOVO} all -s myconfig -K {bestkmer} -R -o soapdenovo -d 10 -p 24  1>ass.log 2>ass.err '''.format( \
               SOAPDENOVO = SOAPDENOVO, bestkmer=bestkmer, outfolder = outfolder, thread = thread, \
               read1 = os.path.join(outfolder,'Trimmomatic','read1.pair.fq'), read2 = os.path.join(outfolder,'Trimmomatic','read2.pair.fq'))
print(command_line)
result = subprocess.check_output(command_line, shell=True)
result = result.decode('utf-8')
print(result)
# Out:
# /home/p/anaconda/anaconda3_5.2.0/bin/SOAPdenovo-127mer all -s myconfig -K 61 -R -o soapdenovo -d 10 -p 24  1>ass.log 2>ass.err

# %%
os.chdir('..')

# %% [markdown]
# ## run CISA

# %%
if not os.path.exists('CISA'):
    os.mkdir('CISA')
os.chdir('CISA')

# %%
shutil.copy('../abyss/abyss-contigs.fa','abyss.fa')
shutil.copy('../velvet/contigs.fa','velvet.fa')
shutil.copy('../spades/contigs.fasta','spades.fa')
shutil.copy('../IDBA-UD/contig.fa','IDBA-UD.fa')
shutil.copy('../soapdenovo/soapdenovo.contig','soapdenovo.fa')
# Out:
# 'soapdenovo.fa'

# %%
ctgs = ['soapdenovo.fa', 'velvet.fa', 'abyss.fa', 'spades.fa', 'IDBA-UD.fa']

# %%
fw=open('ToMerge.config','w')
fw.write('count=5\n')
for i in ctgs:
    fw.write('data={fastafile},title={fastaname}\n'.format(fastafile=i,fastaname=i.split('.')[0]))
fw.write('min_length=400\nMaster_file=Merged.fa\nGap=1\n')
fw.close()

# %%
command_line = '''{MERGE} ToMerge.config '''.format(MERGE = MERGE)
print(command_line)
result = subprocess.check_output(command_line, shell=True)
result = result.decode('utf-8')
print(result)
# Out:
# /home/p/CISA/CISA1.3/Merge.py ToMerge.config
# soapdenovo.fa.p.fa
# Number of contigs: 166
# Length of the longest contig: 157765
# whole:2986723
# N50: 49127
# velvet.fa.p.fa
# Number of contigs: 133
# Length of the longest contig: 291605
# whole:3014292
# N50: 75219
# abyss.fa.p.fa
# Number of contigs: 93
# Length of the longest contig: 278946
# whole:3108220
# N50: 93105
# spades.fa.p.fa
# Number of contigs: 316
# Length of the longest contig: 434654
# whole:3135457
# N50: 102757
# IDBA-UD.fa.p.fa
# Number of contigs: 200
# Length of the longest contig: 341997
# whole:3067591
# N50: 94757

# %%
lis = open('Merge_info').readlines()
genomelens = [int(e.split()[-1]) for e in lis if 'Whole Genome' in e]
genomelen = max(genomelens)
print('max genome length is', genomelen)
# Out:
# max genome length is 3135457

# %%
fw=open('CISA.config','w')
fw.write('''
genome={genomelen}
infile=Merged.fa
outfile=Final.fa
nucmer={NCUMER}
R2_Gap=0.95
CISA={CISAPATH}
makeblastdb={MAKEBLASTDB}
blastn={BLASTN}
'''.format(genomelen=genomelen,NCUMER=NCUMER,CISAPATH=CISAPATH,MAKEBLASTDB=MAKEBLASTDB,BLASTN=BLASTN))
fw.close()

# %%
command_line = '''python {CISA} CISA.config '''.format(CISA = CISA)
print(command_line)
result = subprocess.check_output(command_line, shell=True)
result = result.decode('utf-8')
#print(result)
# Out:
# python /home/p/CISA/CISA1.3/CISA.py CISA.config

# %%
os.chdir('..')

# %% [markdown]
# ## run prokka

# %%
os.getcwd()
# Out:
# '/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus'

# %%
if not os.path.exists('prokka'):
    os.mkdir('prokka')
os.chdir('prokka')

# %%
ls_contigs = list(SeqIO.parse(open('../CISA/Final.fa'), 'fasta'))
outfile = '{bacteriaStrain}.genome.fa'.format(bacteriaStrain=bacteriaStrain)
fout = open(outfile,'w')
for _n, _e in enumerate(ls_contigs):
    fout.write('>'+bacteriaStrain+'.g'+str(_n+1)+'\n'+str(_e.seq)+'\n')
fout.close()

# %%
command_line = '''{PROKKA} --kingdom Bacteria --cpus {thread}  {bacteriaStrain}.genome.fa --outdir . \
                --prefix {bacteriaStrain} --force --metagenome --locustag {bacteriaStrain}'''.format(\
                PROKKA = PROKKA, thread=thread, bacteriaStrain=bacteriaStrain)
print(command_line)
result = subprocess.check_output(command_line, shell=True)
result = result.decode('utf-8')
print(result)
# Out:
# /home/p/prokka/prokka-master/bin/prokka --kingdom Bacteria --cpus 24  MNH08365.genome.fa --outdir .                 --prefix MNH08365 --force --metagenome --locustag MNH08365

# %% [markdown]
# ## run quast

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus'

# %%
command_line = '''python {QUAST} -t {thread} -o quast \
                ./prokka/{bacteriaStrain}.genome.fa ./CISA/abyss.fa.p.fa ./CISA/velvet.fa.p.fa ./CISA/spades.fa.p.fa \
                ./CISA/IDBA-UD.fa.p.fa ./CISA/soapdenovo.fa.p.fa'''.format(\
                QUAST = QUAST, thread=thread, bacteriaStrain=bacteriaStrain)
print(command_line)
result = subprocess.check_output(command_line, shell=True)
result = result.decode('utf-8')
print(result)
# Out:
# python /home/p/quast/quast-4.6.3/quast.py -t 24 -o quast                 ./prokka/MNH08365.genome.fa ./CISA/abyss.fa.p.fa ./CISA/velvet.fa.p.fa ./CISA/spades.fa.p.fa                 ./CISA/IDBA-UD.fa.p.fa ./CISA/soapdenovo.fa.p.fa
# /home/p/quast/quast-4.6.3/quast.py -t 24 -o quast ./prokka/MNH08365.genome.fa ./CISA/abyss.fa.p.fa ./CISA/velvet.fa.p.fa ./CISA/spades.fa.p.fa ./CISA/IDBA-UD.fa.p.fa ./CISA/soapdenovo.fa.p.fa
#
# Version: 4.6.3
#
# System information:
#   OS: Linux-3.10.0-862.6.3.el7.x86_64-x86_64-with-centos-7.5.1804-Core (linux_64)
#   Python version: 3.6.4
#   CPUs number: 24
#
# Started: 2018-08-20 23:07:36
#
# Logging to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/quast.log
#
# CWD: /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus
# Main parameters:
#   Threads: 24, minimum contig length: 500, ambiguity: one, threshold for extensive misassembly size: 1000
#
# Contigs:
#   Pre-processing...
#   1  ./prokka/MNH08365.genome.fa ==> MNH08365.genome
#   2  ./CISA/abyss.fa.p.fa ==> abyss.fa.p
#   3  ./CISA/velvet.fa.p.fa ==> velvet.fa.p
#   4  ./CISA/spades.fa.p.fa ==> spades.fa.p
#   5  ./CISA/IDBA-UD.fa.p.fa ==> IDBA-UD.fa.p
#   6  ./CISA/soapdenovo.fa.p.fa ==> soapdenovo.fa.p
#
# 2018-08-20 23:07:37
# Running Basic statistics processor...
#   Contig files:
#     1  MNH08365.genome
#     2  abyss.fa.p
#     3  velvet.fa.p
#     4  spades.fa.p
#     5  IDBA-UD.fa.p
#     6  soapdenovo.fa.p
#   Calculating N50 and L50...
#     1  MNH08365.genome, N50 = 105921, L50 = 9, Total length = 3157694, GC % = 46.19, # N's per 100 kbp =  0.00
#     2  abyss.fa.p, N50 = 93105, L50 = 11, Total length = 3107797, GC % = 46.27, # N's per 100 kbp =  0.00
#     3  velvet.fa.p, N50 = 75219, L50 = 12, Total length = 3011058, GC % = 46.25, # N's per 100 kbp =  0.00
#     4  spades.fa.p, N50 = 102757, L50 = 9, Total length = 3078612, GC % = 46.15, # N's per 100 kbp =  0.00
#     5  IDBA-UD.fa.p, N50 = 94757, L50 = 10, Total length = 3054657, GC % = 46.17, # N's per 100 kbp =  0.00
#     6  soapdenovo.fa.p, N50 = 49127, L50 = 17, Total length = 2983546, GC % = 46.24, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/basic_stats/Nx_plot.pdf
#   Drawing cumulative plot...
#     saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/basic_stats/GC_content_plot.pdf
#   Drawing MNH08365.genome GC content plot...
#     saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/basic_stats/MNH08365.genome_GC_content_plot.pdf
#   Drawing abyss.fa.p GC content plot...
#     saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/basic_stats/abyss.fa.p_GC_content_plot.pdf
#   Drawing velvet.fa.p GC content plot...
#     saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/basic_stats/velvet.fa.p_GC_content_plot.pdf
#   Drawing spades.fa.p GC content plot...
#     saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/basic_stats/spades.fa.p_GC_content_plot.pdf
#   Drawing IDBA-UD.fa.p GC content plot...
#     saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/basic_stats/IDBA-UD.fa.p_GC_content_plot.pdf
#   Drawing soapdenovo.fa.p GC content plot...
#     saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/basic_stats/soapdenovo.fa.p_GC_content_plot.pdf
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding option to enable it.
#
# 2018-08-20 23:07:40
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2018-08-20 23:07:41
# RESULTS:
#   Text versions of total report are saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/report.html
#   PDF version (tables and plots) is saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/report.pdf
#   Icarus (contig browser) is saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/icarus.html
#   Log saved to /mnt/d/linux/W/MoonNGS/raw/20180813Novogene16species_Human_Methyl/1.rawdata/MNH08365/Tychus/quast/quast.log
#
# Finished: 2018-08-20 23:07:41
# Elapsed time: 0:00:05.077674
# NOTICEs: 1; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!

# %% [markdown]
# ## clean files

# %%
if cleanOrNot:
    os.system('rm -rf {outfolder}/abyss'.format(outfolder=outfolder))
    os.system('rm -rf {outfolder}/IDBA-UD'.format(outfolder=outfolder))
    os.system('rm -rf {outfolder}/kmergenie'.format(outfolder=outfolder))
    os.system('rm -rf {outfolder}/soapdenovo'.format(outfolder=outfolder))
    os.system('rm -rf {outfolder}/spades'.format(outfolder=outfolder))
    os.system('rm -rf {outfolder}/Trimmomatic'.format(outfolder=outfolder))
    os.system('rm -rf {outfolder}/velvet'.format(outfolder=outfolder))
    os.system('rm -rf {outfolder}/CISA'.format(outfolder=outfolder))
    os.system('rm -rf {outfolder}/readlist.txt'.format(outfolder=outfolder))
